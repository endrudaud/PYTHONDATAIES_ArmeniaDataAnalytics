# %% [markdown]
# # <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">Armenian Population Perception Analysis</span>
#
# <span style="font-family: Arial; font-size: 1.2em;"><strong>By Tigran & Andrew</strong></span>
#
# <span style="font-family: Arial; font-size: 1.2em;">This analysis explores the factors influencing the perceptions of the Armenian population on key topics using data from the 2019 Caucasus Barometer survey.</span>

# %%
# Import the functions from the display_content.py script
from display_content import setup_display, create_tabs_for_sections

# Set up the display settings (this can be a placeholder)
setup_display()

# List of sections to create tabs for
sections = [
    'Overview',
    'Dissolution of the Soviet Union',
    "Armenia's Main Enemy",
    "Armenia's Main Friend",
    "Opinion about EU",
    'Summary and Outlook'
]

# Create and display tabs for each section with content displayed inside
create_tabs_for_sections(sections)
# Out:
# <style>/* style.css */
# div.output_subarea {
#     font-family: 'Arial', sans-serif;
#     font-size: 16px;
#     line-height: 1.6;
#     padding: 20px;
# }
#
# h1, h2, h3 {
#     color: #2C3E50;
#     margin-top: 20px;
# }
#
# p {
#     margin-bottom: 10px;
# }</style>
# ...

# %% [markdown]
# # DETAILS ANALYSIS & PROCESS

# %%
# Variable Descriptions and Paginated Table

# Import the functions from the code.py script
from CODE.code import load_data, gather_variable_descriptions, display_paginated_table

# Define the file path
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"

# Load the data and metadata
df, meta = load_data(file_path)

# Gather variable descriptions
desc_df = gather_variable_descriptions(meta)

# Display the paginated table
display_paginated_table(desc_df)


# Value Labels and Data Distribution

# Import the functions from the code.py script
from CODE.code import load_data, extract_value_labels, save_value_labels, plot_armenia_data_distribution

# Define the file path
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"

# Load the data and metadata
df, meta = load_data(file_path)

# Extract value labels
variables_to_explain = [
    'RESPAGE', 'FATEINLF','BUSINRUS','BUSINTUR', 'BUSINGA', 'NEIGHBOR', 
    'USSRDISS', 'EUSUPP', 'EEUSUPNA', 'EEUNSUW', 'EEUSUPW', 'MAINFRN', 
    'MAINENEM', 'PARTYSUPP', 'WORKTYP', 'PERSINC', 'EDUYRS', 'RFAEDUC', 
    'RMOEDUC', 'RELIMP', 'ECONSTN', 'MONYTOT'
]
value_label_df = extract_value_labels(meta, variables_to_explain)

# Save value labels to CSV
save_value_labels(value_label_df)

# Plot Armenia data distribution and display paginated summary table
plot_armenia_data_distribution(df, meta)
# Out:
# IntSlider(value=0, description='Page', max=65)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Variable</th>
#       <th>Description</th>
#       <th>Value Labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>COUNTRY</td>
#       <td>Country</td>
#       <td>1.0: Armenia, 2.0: Azerbaijan, 3.0: Georgia</td>
#     </tr>
#     <tr>
#       <td>RESPONSE</td>
#       <td>Response</td>
#       <td>0.0: Non response, 1.0: Response</td>
#     </tr>
#     <tr>
#       <td>AAPOR</td>
#       <td>AAPOR disposition code</td>
#       <td>11.0: Complete response, 12.0: Partial response, 29.0: Miscellaneous, 47.0: No eligible respondent, 225.0: Respondent unavailable during the fieldwork, 232.0: Physically or mentally unable/incompetent, 321.0: No screener completed, 2111.0: Household-level refusal, 2112.0: Known-respondent refusal, 2331.0: Household-level language problem, 2332.0: Respondent-level language problem</td>
# ...

# %% [markdown]
# ## <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">SECTION I</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">**Dissolution of Soviet Union**</span>
#
# 1. ### Was the dissolution of the Soviet Union a good or bad thing? (USSRDISS)
#
# 2. ### Respondents who support nationalist or conservative parties are more likely to view the dissolution as a bad thing.
#
# 3. ### Respondents with higher personal income are more likely to view the dissolution as a good thing.
#
# 4. ### Respondents with more years of education are more likely to view the dissolution of the Soviet Union as a good thing.
#
# 5. ### Older respondents are more likely to view the dissolution of the Soviet Union as a bad thing compared to younger respondents.

# %%
# SECTION I - Dissolution of the Soviet Union

# Import the functions for Section I
from CODE.code import (load_data, preprocess_data_section1, analyze_parties_vs_ussrdiss, 
                       analyze_income_vs_ussrdiss, analyze_education_vs_ussrdiss, 
                       analyze_age_vs_ussrdiss, perform_logistic_regression_section1, plot_ussrdiss_distributions)

# Load and preprocess data
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = load_data(file_path)
relevant_vars = ['USSRDISS', 'PARTYSUPP', 'PERSINC', 'EDUYRS', 'RESPAGE']
df_filtered = preprocess_data_section1(df, relevant_vars)

# Perform analyses
analyze_parties_vs_ussrdiss(df_filtered)
analyze_income_vs_ussrdiss(df_filtered)
analyze_education_vs_ussrdiss(df_filtered)
analyze_age_vs_ussrdiss(df_filtered)

# Perform logistic regression
perform_logistic_regression_section1(df_filtered, 'PERSINC')

# Plot distributions
plot_ussrdiss_distributions(df_filtered)
# Out:
# USSRDISS by Political Party (Mean of Binary):
# PARTYSUPP
# 101.0    0.557562
# 102.0    1.000000
# 103.0    0.470588
# 104.0    0.414634
# 105.0    0.444444
# 106.0    0.352941
# 107.0    1.000000
# 108.0    0.500000
# 109.0    0.500000
# 301.0    0.422705
# 302.0    0.385093
# 303.0    0.307692
# 304.0    0.217822
# 305.0    0.449275
# 306.0    0.107143
# 307.0    0.666667
# 308.0    0.956522
# 309.0    0.375000
# 999.0    0.500000
# Name: USSRDISS_binary, dtype: float64
#
# Correlation between Personal Income and View on USSR Dissolution: -0.1321
#
# Correlation between Education Years and View on USSR Dissolution: 0.1953
#
# Correlation between Age and View on USSR Dissolution: -0.2738
# Optimization terminated successfully.
#          Current function value: 0.679152
#          Iterations 4
#
# Logistic Regression: PERSINC vs. View on USSR Dissolution
#                            Logit Regression Results
# ...

# %% [markdown]
# # Hypotheses and Results
#
# ## 1. Perception of the Dissolution of the Soviet Union
#
# **Hypothesis 1:**
# Respondents who support nationalist or conservative parties are more likely to view the dissolution of the Soviet Union as a bad thing.
#
# **Null Hypothesis (H0):**
# There is no significant difference in the perception of the dissolution of the Soviet Union between respondents who support nationalist or conservative parties and those who do not.
#
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# ---
#
# **Hypothesis 2:**
# Respondents with higher personal income are more likely to view the dissolution of the Soviet Union as a good thing.
#
# **Null Hypothesis (H0):**
# Personal income level does not significantly influence the perception of the dissolution of the Soviet Union.
#
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# ---
#
# **Hypothesis 3:**
# Respondents with more years of education are more likely to view the dissolution of the Soviet Union as a good thing.
#
# **Null Hypothesis (H0):**
# Education level does not significantly influence the perception of the dissolution of the Soviet Union.
#
# **Result:**
# <span style="color: red;">Null hypothesis rejected.</span>
#
# ---
#
# **Hypothesis 4:**
# Older respondents are more likely to view the dissolution of the Soviet Union as a bad thing compared to younger respondents.
#
# **Null Hypothesis (H0):**
# Age does not significantly influence the perception of the dissolution of the Soviet Union.
#
# **Result:**
# <span style="color: red;">Null hypothesis rejected.</span>

# %% [markdown]
# ## <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">SECTION II</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">**WHO IS THE MAIN ENEMY OF ARMENIA? (MAINENEM)**</span>
#
# 1. ### Respondents who support EU integration are more likely to perceive Russia as Armenia's main enemy.
#
# 2. ### Respondents who consider Russia their main ally are less likely to view Russia as the enemy and more likely to perceive Turkey or Azerbaijan as Armenia's main enemy.
#
# 3. ### Respondents who support nationalist or conservative parties are more likely to perceive Turkey as Armenia's main enemy.
#
# 4. ### Respondents with more years of education are more likely to perceive Russia as Armenia's main enemy.

# %%
# SECTION II - Who is the Main Enemy of Armenia?

# Import the functions for Section II
from CODE.code import (load_data, preprocess_data_section2, analyze_eu_vs_russia_enemy, 
                       analyze_russia_ally_vs_enemy, analyze_party_vs_turkey_enemy, 
                       analyze_education_vs_russia_enemy, perform_logistic_regression_section2, plot_relationships_section2)

# Load and preprocess data
df, meta = load_data(file_path)
df_filtered = preprocess_data_section2(df)

# Perform analyses
analyze_eu_vs_russia_enemy(df_filtered)
analyze_russia_ally_vs_enemy(df_filtered)
analyze_party_vs_turkey_enemy(df_filtered)
analyze_education_vs_russia_enemy(df_filtered)

# Perform logistic regression
perform_logistic_regression_section2(df_filtered, 'EUSUPP')

# Plot relationships
plot_relationships_section2(df_filtered)
# Out:
# EU Integration Support vs. Perception of Russia as Armenia's Main Enemy:
# MAINENEM_mapped     False     True
# EUSUPP
# 1.0              0.836735  0.163265
# 2.0              0.870370  0.129630
# 3.0              0.669261  0.330739
# 4.0              0.604585  0.395415
# 5.0              0.408602  0.591398
#
# Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy:
# MAINENEM_mapped   Armenia  Azerbaijan  Everybody  Foreigners   Georgia  \
# MAINFRN
# False            0.011134    0.409919   0.002024    0.001012  0.001012
#
# MAINENEM_mapped      Iran  Muslim countries  Our country itself    Russia  \
# MAINFRN
# False            0.003036          0.002024            0.001012  0.407895
#
# MAINENEM_mapped    Turkey       USA  Venezuela
# MAINFRN
# False            0.148785  0.011134   0.001012
#
# Nationalist/Conservative Parties vs. Perception of Turkey as Armenia's Main Enemy:
# MAINENEM_mapped     False     True
# PARTYSUPP
# ...

# %% [markdown]
# # Hypotheses and Results
#
# ## 2. Who is the Main Enemy of Armenia? (MAINENEM)
#
# **Hypothesis 1:**
# Respondents who support EU integration are more likely to perceive Russia as Armenia's main enemy.
#
# **Null Hypothesis (H0):**
# Support for EU integration does not significantly influence the perception of Russia as Armenia's main enemy.
#
# **Result:**
# <span style="color: red;">Null hypothesis rejected.</span>
#
# ---
#
# **Hypothesis 2:**
# Respondents who consider Russia their main ally are more likely to perceive Turkey or Azerbaijan as Armenia's main enemy.
#
# **Null Hypothesis (H0):**
# Perception of Russia as a main ally does not significantly influence the perception of Turkey or Azerbaijan as Armenia's main enemy.
#
# **Result:**
# <span style="color: green;">Null hypothesis confirmed for Azerbaijan</span>, <span style="color: red;">rejected for Turkey</span>.
#
# ---
#
# **Hypothesis 3:**
# Respondents who support nationalist or conservative parties are more likely to perceive Turkey as Armenia's main enemy.
#
# **Null Hypothesis (H0):**
# Support for nationalist or conservative parties does not significantly influence the perception of Turkey as Armenia's main enemy.
#
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# ---
#
# **Hypothesis 4:**
# Respondents with more years of education are more likely to perceive Russia as Armenia's main enemy.
#
# **Null Hypothesis (H0):**
# Education level does not significantly influence the perception of Russia as Armenia's main enemy.
#
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>

# %% [markdown]
# ## <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">SECTION III</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">WHO IS THE MAIN FRIEND OF ARMENIA? MAINFRN</span>
#
# ### 1. <span style="font-family: Arial;">Older respondents are more likely to perceive Russia as Armenia's main friend compared to younger respondents.</span>
#
# ### 2. <span style="font-family: Arial;">Respondents from higher-income families are more likely to perceive the European Union (EU) or the United States as Armenia's main friend.</span>
#
# ### 3. <span style="font-family: Arial;">Respondents who perceive Turkey or Azerbaijan as Armenia's main enemy are more likely to perceive Russia as Armenia's main friend.</span>

# %%
# SECTION III - Who is the Main Friend of Armenia?

# Import the functions for Section III
from CODE.code import (load_data, preprocess_data_section3, analyze_age_vs_russia_friend, 
                       analyze_income_vs_eu_usa_friend, analyze_enemy_vs_russia_friend, 
                       perform_logistic_regression_section3, plot_relationships_section3)

# Load and preprocess data
df, meta = load_data(file_path)
df_filtered = preprocess_data_section3(df)

# Perform analyses
analyze_age_vs_russia_friend(df_filtered)
analyze_income_vs_eu_usa_friend(df_filtered)
analyze_enemy_vs_russia_friend(df_filtered)

# Perform logistic regression
perform_logistic_regression_section3(df_filtered, 'RESPAGE', df_filtered['MAINFRN_mapped'] == 'Russia')

# Plot relationships
plot_relationships_section3(df_filtered)
# Out:
# Correlation between Age and Perception of Russia as Armenia's Main Friend: 0.0071
#
# Income vs. Perception of EU/USA as Armenia's Main Friend:
# MAINFRN_mapped     False     True
# PERSINC
# 1.0             0.750000  0.250000
# 2.0             0.500000  0.500000
# 3.0             0.933333  0.066667
# 4.0             0.870130  0.129870
# 5.0             0.898551  0.101449
# 6.0             0.832184  0.167816
# 7.0             0.593496  0.406504
# 8.0             0.881620  0.118380
# 9.0             0.506329  0.493671
#
# Perception of Turkey/Azerbaijan as Enemy vs. Perception of Russia as Armenia's Main Friend:
# MAINFRN_mapped      False     True
# MAINENEM_mapped
# False            0.977901  0.022099
# True             0.282511  0.717489
# Optimization terminated successfully.
#          Current function value: 0.686774
#          Iterations 4
#
# Logistic Regression: RESPAGE vs. Perception of MAINFRN_mapped
#                            Logit Regression Results
# ...

# %% [markdown]
# **Hypothesis 1:**
# Older respondents are more likely to perceive Russia as Armenia's main friend compared to younger respondents.
# **Null Hypothesis (H0):**
# Age does not significantly influence the perception of Russia as Armenia's main friend.
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# **Hypothesis 2:**
# Respondents from higher-income families are more likely to perceive the European Union (EU) or the United States as Armenia's main friend.
# **Null Hypothesis (H0):**
# Income level does not significantly influence the perception of the EU or the United States as Armenia's main friend.
# **Result:**
# <span style="color: red;">Null hypothesis rejected.</span>
#
# **Hypothesis 3:**
# Respondents who perceive Turkey or Azerbaijan as Armenia's main enemy are more likely to perceive Russia as Armenia's main friend.
# **Null Hypothesis (H0):**
# Perception of Turkey or Azerbaijan as Armenia's main enemy does not significantly influence the perception of Russia as Armenia's main friend.
# **Result:**
# <span style="color: red;">Null hypothesis rejected.</span>

# %% [markdown]
# ## <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">SECTION IV</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">WHAT IS YOUR OPINION ABOUT EU?</span>
#
# ### <span style="font-family: Arial; font-size: 1.2em;">1. Younger respondents are more likely to have a positive opinion about the EU compared to older respondents. EUSUPP</span>
#
# ### <span style="font-family: Arial; font-size: 1.2em;">2. Respondents who support liberal or pro-European political parties are more likely to have a positive opinion of the EU.</span>
#
# ### <span style="font-family: Arial; font-size: 1.2em;">3. Respondents with more years of education are more likely to have a positive opinion of the EU.</span>
#
# ### <span style="font-family: Arial; font-size: 1.2em;">4. Respondents who consider religion very important may have a more skeptical opinion of the EU, especially if they perceive it as secular or opposed to traditional values.</span>

# %%
from CODE.code import (
    load_data, preprocess_data_section4, analyze_age_vs_eu_support, 
    analyze_party_vs_eu_support, analyze_education_vs_eu_support, 
    analyze_religion_vs_eu_support, perform_logistic_regression_section4, 
    plot_relationships_section4
)

# Define the file path and relevant variables
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
relevant_vars = ['EUSUPP', 'RESPAGE', 'PARTYSUPP', 'EDUYRS', 'RELIMP']

# Load the data
df, meta = load_data(file_path)

# Preprocess the data
df_filtered = preprocess_data_section4(df, relevant_vars)

# Define the mapping for liberal/pro-European parties
liberal_pro_european_parties = {
    1.0: 'Liberal Party',
    2.0: 'Pro-European Party',
    # Add actual mappings as needed
}

# Perform analyses
age_eu_support_corr = analyze_age_vs_eu_support(df_filtered)
liberal_party_eu_support = analyze_party_vs_eu_support(df_filtered, liberal_pro_european_parties)
education_eu_support_corr = analyze_education_vs_eu_support(df_filtered)
religion_eu_support_corr = analyze_religion_vs_eu_support(df_filtered)

# Perform logistic regressions
model_age = perform_logistic_regression_section4(df_filtered, 'RESPAGE')
model_edu = perform_logistic_regression_section4(df_filtered, 'EDUYRS')
model_religion = perform_logistic_regression_section4(df_filtered, 'RELIMP')

# Plot relationships
plot_relationships_section4(df_filtered)
# Out:
# Correlation between Age and Positive Opinion of the EU: -0.1382
#
# Support for Liberal/Pro-European Parties vs. Positive Opinion of the EU:
# Empty DataFrame
# Columns: []
# Index: []
#
# Correlation between Education Years and Positive Opinion of the EU: 0.1244
#
# Correlation between Religious Importance and Opinion of the EU: -0.0603
# Optimization terminated successfully.
#          Current function value: 0.649858
#          Iterations 5
#
# Logistic Regression: RESPAGE vs. Positive Opinion of the EU
#                            Logit Regression Results
# ...
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 02 Sep 2024   Pseudo R-squ.:                 0.01048
# Time:                        18:49:52   Log-Likelihood:                -651.81
# ...

# %% [markdown]
# **Hypothesis 1:**
# Younger respondents are more likely to have a positive opinion about the EU compared to older respondents.
# **Null Hypothesis (H0):**
# Age does not significantly influence opinions about the EU.
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# **Hypothesis 2:**
# Respondents with more years of education are more likely to have a positive opinion of the EU.
# **Null Hypothesis (H0):**
# Education level does not significantly influence opinions about the EU.
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>
#
# **Hypothesis 3:**
# Respondents who consider religion very important may have a more skeptical opinion of the EU, especially if they perceive it as secular or opposed to traditional values.
# **Null Hypothesis (H0):**
# The perceived importance of religion does not significantly influence opinions about the EU.
# **Result:**
# <span style="color: green;">Fail to reject the null hypothesis.</span>

# %% [markdown]
# ## <span style="color: #2E86C1; font-family: Arial; font-size: 2.5em;">Final Analysis and Conclusion</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">The analysis aimed to explore the factors influencing the Armenian population's perceptions on four key topics: the dissolution of the Soviet Union, Armenia's main enemy, Armenia's main friend, and opinions about the European Union (EU), using data from the Caucasus Barometer 2019 survey.</span>
#
# ### 1. Perception of the Dissolution of the Soviet Union
# Contrary to our expectations, there was no significant correlation between respondents' political affiliations or income levels and their views on the dissolution of the Soviet Union. However, education and age played a significant role: respondents with higher education levels were more likely to view the dissolution positively, as were younger respondents, indicating a generational shift in perspectives.
#
# ### 2. Perception of Armenia's Main Enemy
# The analysis showed that respondents who support EU integration were more likely to perceive Russia as Armenia's main enemy, while those who view Russia as an ally tended to see Azerbaijan as the primary enemy. Contrary to our expectations, political party affiliation did not significantly influence perceptions of Turkey as Armenia's main enemy, suggesting that Armenian political parties may not be effectively shaping public opinion on this issue. Additionally, education level did not significantly impact the perception of Russia as Armenia's main enemy.
#
# ### 3. Perception of Armenia's Main Friend
# The perception of Russia as Armenia's main friend did not differ significantly between older and younger generations, counter to our initial assumptions as the older generation was inclined to believe that the dissolution of the USSR was bad. This indicates to us that people have the wrong notion about the USSR and don't perceive it as a Russian communist empire. However, this is a topic of further research. Respondents who identified Turkey or Azerbaijan as Armenia's main enemy were more likely to consider Russia a friend, highlighting the complex geopolitical dynamics at play.
#
# ### 4. Opinion about the European Union (EU)
# Surprisingly, none of the hypothesized factors—age, education, or religiosity—significantly influenced respondents' opinions about the EU. This suggests that public opinion on the EU is less affected by demographic or socio-cultural factors than by other, perhaps more immediate, concerns. This will also require further research.
#
# <span style="font-family: Arial; font-size: 1.2em;">Our findings indicate that traditional predictors such as political affiliation and income levels have limited influence on certain perceptions within the Armenian population, particularly regarding the dissolution of the Soviet Union and views on the EU. In contrast, education and age were found to significantly influence opinions on the dissolution, reflecting broader societal shifts.</span>
#
# <span style="font-family: Arial; font-size: 1.2em;">To sum up, we want to note again that the data was collected in 2019, prior to the Second Nagorno-Karabakh War and the subsequent ethnic cleansing and mass migration of Armenians from Nagorno-Karabakh, events which have significantly impacted public opinion. Preliminary reports and limited surveys suggest a dramatic shift in perceptions. As a spoiler, a significant portion of the population now view Russia as a major threat and France as Armenia's main ally. Comprehensive data from the latest Caucasus Barometer survey, expected next year, will provide data for 2024, and we plan to compare these findings to our current analysis to understand how recent events have reshaped Armenian public opinion.</span>
