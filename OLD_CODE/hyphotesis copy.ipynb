# %%
#'RESPAGE', 'FATEINLF','BUSINRUS','BUSINTUR', 'BUSINGA', 'NEIGHBOR', 'USSRDISS', 'EUSUPP', 'EEUSUPNA', 'EEUNSUW', 'EEUSUPW', 'MAINFRN', 'MAINENEM', 'PARTYSUPP', 'WORKTYP', 'PERSINC', 'EDUYRS', 'RFAEDUC', 'RMOEDUC', 'RELIMP', 'ECONSTN', 'MONYTOT'

# %% [markdown]
# ## Printing the label descriptions

# %%
import pandas as pd
import pyreadstat

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Function to print the description for each variable's values
def print_variable_descriptions(meta):
    for var_name in meta.column_names:
        if var_name in meta.variable_to_label:
            print(f"Variable: {var_name} - {meta.column_labels[meta.column_names.index(var_name)]}")
            value_labels = meta.value_labels.get(meta.variable_to_label.get(var_name), {})
            #for value, label in value_labels.items():
                #print(f"  Value: {value} - Description: {label}")
            print()  # Add a blank line between variables for readability

# Print the descriptions for each variable's values
print_variable_descriptions(meta)
# Out:
# Variable: COUNTRY - Country
#
# Variable: RESPONSE - Response
#
# Variable: AAPOR - AAPOR disposition code
#
# Variable: SETTYPE - Stratum
#
# Variable: RESPSEX - Respondent's sex
#
# Variable: RESPAGE - Respondent's age
#
# Variable: AGEGROUP - Age groups
#
# Variable: ACTCHORE - Helped a neighbor or a friend with some household chores or childcare?
#
# Variable: ACTRESDT - Helped someone to resolve a dispute?
#
# Variable: ACTCLEAN - Helped cleaning public space?
#
# Variable: ACTTHEA - Went to a theatre or cinema?
#
# Variable: ACTREST - Went to a restaurant?
#
# Variable: ACTVLNT - Did volunteer work without expecting compensation?
#
# Variable: ACTCOMM - Made a comment online?
#
# Variable: ACTDNCH - Donated money to a church or mosque?
#
# Variable: ACTNRCHN - Donated money to a nonreligious charity?
#
# Variable: ACTPBLM - Attended a public meeting?
#
# Variable: ACTSPET - Signed a petition or a demand, request?
#
# Variable: ACTDON - Made a donation to a trustworthy organization
#
# Variable: RATEHAP - How happy would you say you are?
#
# Variable: EMONOW - How do you feel now?
#
# Variable: GALLTRU - Most people can be trusted or you cannot be too careful?
#
# Variable: CIGAVGD - On average, how many cigarettes do you smoke per day?
#
# Variable: HLTHRAT - Overall, how would you rate your health?
#
# Variable: DISCPRPR - How often do you discuss private problems with your close relatives and friends?
#
# Variable: BUSINUSA - Do you approve or disapprove doing business with an American?
#
# Variable: BUSINARM - Do you approve or disapprove doing business with an Armenian?
#
# Variable: BUSINAZE - Do you approve or disapprove doing business with an Azerbaijani?
#
# Variable: BUSINITA - Do you approve or disapprove doing business with an Italian?
#
# Variable: BUSINARA - Do you approve or disapprove doing business with an Arab?
#
# Variable: BUSINGEO - Do you approve or disapprove doing business with a Georgian?
#
# Variable: BUSINIRA - Do you approve or disapprove doing business with an Iranian?
#
# Variable: BUSINJEW - Do you approve or disapprove doing business with a Jew?
#
# Variable: BUSINKUR - Do you approve or disapprove doing business with a Kurd, Yezidi?
#
# Variable: BUSINRUS - Do you approve or disapprove doing business with a Russian?
#
# Variable: BUSINTUR - Do you approve or disapprove doing business with a Turk?
#
# Variable: BUSINUKR - Do you approve or disapprove doing business with a Ukrainian?
#
# Variable: BUSININD - Do you approve or disapprove doing business with an Indian?
#
# Variable: BUSINMOL - Do you approve or disapprove doing business with an Molokans?
#
# Variable: BUSINABK - Do you approve or disapprove doing business with an Abkhaz?
#
# Variable: BUSINOSS - Do you approve or disapprove doing business with an Ossetian?
#
# Variable: BUSINARG - Do you approve or disapprove doing business with an Armenian living in Georgia?
#
# Variable: BUSINAZG - Do you approve or disapprove doing business with an Azerbaijani living in Georgi
#
# Variable: BUSINJW - Whether you approve or disapprove people doing business with a Jehovah's Witness
#
# Variable: BUSINGA - Whether you approve or disapprove of people doing business with a homosexual?
#
# Variable: MARWUSA - Approve or disapprove of women of your ethnicity marrying an American?
#
# Variable: MARWARM - Approve or disapprove of women of your ethnicity marrying an Armenian?
#
# Variable: MARWAZE - Approve or disapprove of women of your ethnicity marrying an Azerbaijani?
#
# Variable: MARWITA - Approve or disapprove of women of your ethnicity marrying an Italian?
#
# Variable: MARWARA - Approve or disapprove of women of your ethnicity marrying an Arab?
#
# Variable: MARWGEO - Approve or disapprove of women of your ethnicity marrying a Georgian?
#
# Variable: MARWIRA - Approve or disapprove of women of your ethnicity marrying an Iranian?
#
# Variable: MARWJEW - Approve or disapprove of women of your ethnicity marrying a Jew?
#
# Variable: MARWKUR - Approve or disapprove of women of your ethnicity marrying a Kurd, Yezidi?
#
# Variable: MARWRUS - Approve or disapprove of women of your ethnicity marrying a Russian?
#
# Variable: MARWTUR - Approve or disapprove of women of your ethnicity marrying a Turk?
#
# Variable: MARWUKR - Approve or disapprove of women of your ethnicity marrying a Ukrainian?
#
# Variable: MARWIND - Approve or disapprove of women of your ethnicity marrying an Indian?
#
# Variable: MARWMOL - Would you approve or disapprove of women of your ethnicity marrying a Molokan?
#
# Variable: MARWABK - Approve or disapprove of women of your ethnicity marrying an Abkhaz?
#
# Variable: MARWOSS - Approve or disapprove of women of your ethnicity marrying an Ossetian?
#
# Variable: MARWARG - Approve or disapprove of women of your ethnicity marrying Armenian living in Geo
#
# Variable: MARWAZG - Approve or disapprove of women of your ethnicity marrying Azerbaijani living in
#
# Variable: MARWJW - Approve or disapprove of people like you marrying a Jehovah's Witness?
#
# Variable: CLRLABR - Do you have a close relative currently living abroad?
#
# Variable: RELLVAE - Close relative in UAE
#
# Variable: RELLVAF - Close relative in Afganistan
#
# Variable: RELLVAG - Close relative in Argentina
#
# Variable: RELLVAM - Close relative in Armenia
#
# Variable: RELLVAT - Close relative in Austria
#
# Variable: RELLVAU - Close relative in Australia
#
# Variable: RELLVAZ - Close relative in Azerbaijan
#
# Variable: RELLVBE - Close relative in Belgium
#
# Variable: RELLVBG - Close relative in Bulgaria
#
# Variable: RELLVBR - Close relative in Brasil
#
# Variable: RELLVBY - Close relative in Belarus
#
# Variable: RELLVCA - Close relative in Canada
#
# Variable: RELLVCH - Close relative in Switzerland
#
# Variable: RELLVCN - Close relative in China
#
# Variable: RELLVCUK - Close relative in UK
#
# Variable: RELLVCY - Close relative in Cyprus
#
# Variable: RELLVCZ - Close relative in Czech republic
#
# Variable: RELLVDE - Close relative in Germany
#
# Variable: RELLVDK - Close relative in Denmark
#
# Variable: RELLVEE - Close relative in Estonia
#
# Variable: RELLVES - Close relative in Spain
#
# Variable: RELLVEU - Close relative in EU
#
# Variable: RELLVFR - Close relative in France
#
# Variable: RELLVGE - Close relative in Georgia
#
# Variable: RELLVGR - Close relative in Greece
#
# Variable: RELLVGU - Close relative in Guinea
#
# Variable: RELLVHU - Close relative in Hungary
#
# Variable: RELLVIC - Close relative in Iceland
#
# Variable: RELLVID - Close relative in India
#
# Variable: RELLVIE - Close relative in Ireland
#
# Variable: RELLVIL - Close relative in Israel
#
# Variable: RELLVIQ - Close relative in Iraq
#
# Variable: RELLVIR - Close relative in Iran
#
# Variable: RELLVIT - Close relative in Italy
#
# Variable: RELLVJO - Close relative in Jordan
#
# Variable: RELLVKG - Close relative in Kyrgyztan
#
# Variable: RELLVKZ - Close relative in Kazakhstan
#
# Variable: RELLVLT - Close relative in Lithuania
#
# Variable: RELLVLV - Close relative in Latvia
#
# Variable: RELLVMD - Close relative in Moldova
#
# Variable: RELLVMX - Close relative in Mexico
#
# Variable: RELLVND - Close relative in Netherlands
#
# Variable: RELLVNO - Close relative in Norway
#
# Variable: RELLVPL - Close relative in Poland
#
# Variable: RELLVPS - Close relative in Palestine
#
# Variable: RELLVPT - Close relative in Portugal
#
# Variable: RELLVQA - Close relative in Qatar
#
# Variable: RELLVRS - Close relative in Serbia
#
# Variable: RELLVRU - Close relative in Russia
#
# Variable: RELLVSA - Close relative in Arabia
#
# Variable: RELLVSE - Close relative in Sweden
#
# Variable: RELLVSG - Close relative in Singapore
#
# Variable: RELLVSY - Close relative in Syria
#
# Variable: RELLVTM - Close relative in Turkmenistan
#
# Variable: RELLVTR - Close relative in Turkey
#
# Variable: RELLVUA - Close relative in Ukraine
#
# Variable: RELLVUK - Close relative in Great Britain
#
# Variable: RELLVUS - Close relative in USA
#
# Variable: RELLVUZ - Close relative in Uzbekistan
#
# Variable: CLFRDAB - Do you have any close friends currently living abroad?
#
# Variable: FRNDLVAB - Close friend in Abkhazia
#
# Variable: FRNDLVAE - Close friend in UAE
#
# Variable: FRNDLVAF - Close friend in Afganistan
#
# Variable: FRNDLVAM - Close friend in Armenia
#
# Variable: FRNDLVAR - Close friend in Argentina
#
# Variable: FRNDLVAT - Close friend in Austria
#
# Variable: FRNDLVAU - Close friend in Australia
#
# Variable: FRNDLVAZ - Close friend in Azerbaijan
#
# Variable: FRNDLVBE - Close friend in Belgium
#
# Variable: FRNDLVBY - Close friend in Belarus
#
# Variable: FRNDLVCA - Close friend in Canada
#
# Variable: FRNDLVCH - Close friend in Switzerland
#
# Variable: FRNDLVCZ - Close friend in Czech republic
#
# Variable: FRNDLVDE - Close friend in Germany
#
# Variable: FRNDLVDK - Close friend in Denmark
#
# Variable: FRNDLVEE - Close friend in Estonia
#
# Variable: FRNDLVES - Close friend in Spain
#
# Variable: FRNDLVEU - Close friend in EU
#
# Variable: FRNDLVFR - Close friend in France
#
# Variable: FRNDLVGE - Close friend in Georgia
#
# Variable: FRNDLVGR - Close friend in Greece
#
# Variable: FRNDLVIE - Close friend in Ireland
#
# Variable: FRNDLVIL - Close friend in Israel
#
# Variable: FRNDLVIQ - Close friend in Iraq
#
# Variable: FRNDLVIR - Close friend in Iran
#
# Variable: FRNDLVIS - Close friend in Iceland
#
# Variable: FRNDLVIT - Close friend in Italy
#
# Variable: FRNDLVJP - Close friend in Japan
#
# Variable: FRNDLVKR - Close friend in Korea
#
# Variable: FRNDLVKZ - Close friend in Kazakhstan
#
# Variable: FRNDLVLB - Close friend in Lebanon
#
# Variable: FRNDLVLT - Close friend in Lithuania
#
# Variable: FRNDLVLV - Close friend in Latvia
#
# Variable: FRNDLVLX - Close friend in Luxembourg
#
# Variable: FRNDLVMD - Close friend in Moldova
#
# Variable: FRNDLVND - Close friend in Netherlands
#
# Variable: FRNDLVNO - Close friend in Norway
#
# Variable: FRNDLVPL - Close friend in Poland
#
# Variable: FRNDLVPT - Close friend in Portugal
#
# Variable: FRNDLVRO - Close friend in Romania
#
# Variable: FRNDLVRU - Close friend in Russia
#
# Variable: FRNDLVSE - Close friend in Sweden
#
# Variable: FRNDLVSK - Close friend in Slovakia
#
# Variable: FRNDLVSY - Close friend in Syria
#
# Variable: FRNDLVTM - Close friend in Turkmenistan
#
# Variable: FRNDLVTR - Close friend in Turkey
#
# Variable: FRNDLVUA - Close friend in Ukraine
#
# Variable: FRNDLVUK - Close friend in Great Britain
#
# Variable: FRNDLVUS - Close friend in USA
#
# Variable: FRNDLVUU - Close friend in Uruguai
#
# Variable: FRNDLVUY - Close friend in Uruguay
#
# Variable: FRNDLVUZ - Close friend in Uzbekistan
#
# Variable: FATEINLF - Please tell me which comes closest to your view?
#
# Variable: NEIGHBOR - Which of these people would you not wish to have your neighbors most?
#
# Variable: NEIGHOTH - Which of these people would you not wish to have your neighbors most? Other spec
#
# Variable: ACCVODK - What age do you think it is acceptable for a woman to drink strong alcohol
#
# Variable: ACCTOBA - What age do you think it is acceptable for a woman to smoke tobacco
#
# Variable: ACCSEPL - What age is acceptable for woman to live separately from parents before marriage
#
# Variable: ACCSEBM - What age is acceptable for a woman to have sexual relations before marriage
#
# Variable: ACCMARR - What age do you think it is acceptable for a woman to get married
#
# Variable: ACCCOHB - What age is acceptable for a woman to cohabit with a man without marriage
#
# Variable: GENBREA - Who should normally be the breadwinner in families in COUNTRY – a man or a woman
#
# Variable: GENBRER - Majority of families in Georgia today, who is the breadwinner–a man or a woman?
#
# Variable: IDEALNCH - What is the ideal number of children per family in COUNTRY?
#
# Variable: GNDPREF - If a family has one child, what would be the preferred gender of the child?
#
# Variable: CAREPRNTS - In your opinion, who should take care of parents more ?
#
# Variable: APTINHERT - The household only owns one apartment.Who should inherit the apartment?
#
# Variable: APTINHOTH - The household only owns one apartment. Who should inherit the apartment? Other
#
# Variable: TRUPOLLRN - Do you trust or distrust the results of public opinion polls?
#
# Variable: TRUOS - Please, tell me, in general, how much do you trust or distrust the information p
#
# Variable: POLDIRN - Which direction domestic politics of the country are going?
#
# Variable: CNTPROS - Which of the following statements you agree with and to what extent?
#
# Variable: IMPISS1 - What do you think is the most important issue facing COUNTRY at the moment?
#
# Variable: IMPISS1O - The most important issue facing COUNTRY at the moment? Other specified
#
# Variable: IMPISS2 - And the second most important issue facing COUNTRY at the moment?
#
# Variable: IMPISS2O - The second most important issue facing COUNTRY at the moment? Other specified
#
# Variable: REVPARTP - Have you participated in the events of April 2018 in the following ways? Partici
#
# Variable: REVPARTBR - Have you participated in the events of April 2018 in the following ways? Blockin
#
# Variable: REVPARTG - Have you participated in the events of April 2018 in the following ways? Blockin
#
# Variable: REVPARTS - Have you participated in the events of April 2018 in the following ways? Joining
#
# Variable: REVPARTD - Have you participated in the events of April 2018 in the following ways? Publish
#
# Variable: REVPARTF - Have you participated in the events of April 2018 in the following ways? Followi
#
# Variable: REVPARTOT - Have you participated in the events of April 2018 in the following ways? Other
#
# Variable: REVPARTOTS - Have you participated in the events of April 2018 in the following ways? Other s
#
# Variable: REVEXP1 - What kind of expectations did you have from the events (known as “Velvet Revol
#
# Variable: REVEXP2 - To what extent have your expectations been met in regards to the events (known a
#
# Variable: REFLANG - Making the teaching of university courses on “Armenian language” and “Arme
#
# Variable: REFCRC - Removing the “History of Armenian church” course from the curriculum of publ
#
# Variable: REFRET - Possibility for early retirement of the constitutional court members
#
# Variable: REFVET - Examining the conscientiousness of the judges (vetting)
#
# Variable: REFIST - Adaptation of the Istanbul Convention (“Convention on preventing and combating
#
# Variable: REFINT - Reduction of income tax rate
#
# Variable: REFHLT - Mandatory health insurance, with a 6% taxation from salaries
#
# Variable: REFREF - Constitutional Referendum
#
# Variable: ISTTEXT - Have you read the Istanbul Convention text?
#
# Variable: TRUHLTH - How much do you trust or distrust healthcare system?
#
# Variable: TRUBANK - How much do you trust or distrust banks?
#
# Variable: TRUEDUC - How much do you trust or distrust educational system?
#
# Variable: TRUARMY - How much do you trust or distrust army?
#
# Variable: TRUCRTS - How much do you trust or distrust court system?
#
# Variable: TRUNGOS - How much do you trust or distrust NGOs?
#
# Variable: TRUPARL - How much do you trust or distrust parliament?
#
# Variable: TRUEXEC - How much do you trust or distrust executive government?
#
# Variable: TRUPRES - How much do you trust or distrust president?
#
# Variable: TRUPOLI - How much do you trust or distrust police?
#
# Variable: TRUPPS - How much do you trust or distrust political parties?
#
# Variable: TRUMEDI - How much do you trust or distrust media?
#
# Variable: TRULOCG - How much do you trust or distrust local government?
#
# Variable: TRURELI - How much do you trust or distrust religious institutions?
#
# Variable: TRUOMB - How much do you trust or distrust ombudsman?
#
# Variable: TRUSTEU - How much do you trust or distrust EU?
#
# Variable: TRUSTUN - How much do you trust or distrust UN?
#
# Variable: QUALINF - How well TVs inform the population about what is actually going on in COUNTRY?
#
# Variable: FREESPK - Do people like yourself have the right to openly say what they think?
#
# Variable: FAIRTRT - Are people like yourself treated fairly by the government?
#
# Variable: LPROS - To what extent do you approve the persecution/prosecution of the representatives
#
# Variable: GOVTROL - Government as a parent vs Government as an employee
#
# Variable: OBJCOUR - Courts favor some citizens over others, or treat all citizens equally?
#
# Variable: PROTEST - People should vs should not participate in protest actions
#
# Variable: PARTYSUPP - Which political party is closest to you?
#
# Variable: PARTYSUPO - Which political party is closest to you? Other specified
#
# Variable: PARTYSUPS - Towards which political party do you have the most sympathy for?
#
# Variable: PARTYSUSO - Towards which political party do you have the most sympathy for? Other specified
#
# Variable: VOTPRCP - Would you participate in the national elections next Sunday?
#
# Variable: VOTLELE - Did you vote in the Parliamentary elections on December 9, 2018?
#
# Variable: VOTLEL1 - Did you vote in the first round of Presidential elections on October 28, 2018?
#
# Variable: VOTLEL2 - Did you vote in the second round of Presidential elections in November 28,2018?
#
# Variable: ELCOND - Would you say that those elections were conducted…
#
# Variable: NATOSUPP - To what extent would you support countrys membership in NATO?
#
# Variable: NATNSUPW - What is the main reason you would not support COUNTRY's membership in NATO?
#
# Variable: NATNSUPO - What is the main reason you would not support COUNTRY's membership in NATO? Othe
#
# Variable: NATOSUPW - What is the main reason you would support COUNTRY's membership in NATO?
#
# Variable: NATOSUPO - What is the main reason you would support COUNTRY's membership in NATO? Other sp
#
# Variable: EUSUPP - To what extent would you support COUNTRY's membership in the European Union?
#
# Variable: EUNSUPW - What is the main reason you would not support COUNTRY's membership in the EU?
#
# Variable: EUNSUPO - What is the main reason you would not support COUNTRY's membership in the EU? Ot
#
# Variable: EUSUPWHY - What is the main reason you would support COUNTRY's membership in the EU?
#
# Variable: EUSUPWHO - What is the main reason you would support COUNTRY's membership in the EU? Other
#
# Variable: EEUSUPNA - To what extent do you support Armenia’s membership in the Eurasian Economic Unio
#
# Variable: EEUNSUW - What is the main reason you would not support Armenia's membership in the Eurasi
#
# Variable: EEUNSUWO - What is the main reason you would not support Armenia's membership in the Eurasi
#
# Variable: EEUSUPW - What is the main reason you would support Armenia's membership in the Eurasian U
#
# Variable: EEUSUPWO - What is the main reason you would support Armenia's membership in the Eurasian U
#
# Variable: COOPEU - Assessment of the results of Armenia's cooperation with the EU
#
# Variable: COOPNATO - Assessment of the results of Armenia's cooperation with NATO
#
# Variable: COOPEEU - Assessment of the results of Armenia's membership into EEU
#
# Variable: COOPCSTO - Assessment of the results of Armenia's membership into CSTO
#
# Variable: RUBETEUN - COUNTRY benefits more if says no to EU-NATO at the expence relations with Russia
#
# Variable: MAINFRN - Which country is currently the main friend of country?
#
# Variable: MAINENEM - Which country is currently the main enemy of country?
#
# Variable: USSRDISS - Was the dissolution of the Soviet Union a good thing or a bad thing for COUNTRY?
#
# Variable: USSRPOIN - Dissolution of USSR a good thing: COUNTRY became independent
#
# Variable: USSRPOWE - Dissolution of USSR a good thing: We have a chance to get closer to the West
#
# Variable: USSRPOCU - Dissolution of USSR a good thing: Opportunity for our culture to flourish
#
# Variable: USSRPOHR - Dissolution of USSR a good thing: Human rights are protected
#
# Variable: USSRPOCM - Dissolution of USSR a good thing: People can start business/commertial activity
#
# Variable: USSRPOFO - Dissolution of USSR a good thing: Wider selection of consumer goods and food
#
# Variable: USSRPOEL - Dissolution of USSR a good thing: We can elect our own government
#
# Variable: USSRPOEX - Dissolution of USSR a good thing: People can openly express their opinions
#
# Variable: USSRPOTR - Dissolution of USSR a good thing: We can travel abroad
#
# Variable: USSRPOLN - Dissolution of USSR a good thing: We can better sustain our language, uniqueness
#
# Variable: USSRPOOT - Dissolution of USSR a good thing: Other
#
# Variable: USSRPOOTS - Dissolution of USSR a good thing: Other specified
#
# Variable: USSRNEEC - Dissolution of USSR a bad thing: People's economic situation has worsened
#
# Variable: USSRNETI - Dissolution of USSR a bad thing: Ties with friends and relatives were severed
#
# Variable: USSRNEGHA - Dissolution of USSR a bad thing: People started judging others,because identity
#
# Variable: USSRNTRA - Dissolution of USSR a bad thing: Harder to travel in republics of former USSR
#
# Variable: USSRNEWA - Dissolution of USSR a bad thing: War started in [Abkhazia and South Ossetia] | [
#
# Variable: USSRNECC - Dissolution of USSR a bad thing: Civil war started inside of COUNTRY
#
# Variable: USSRNESS - Dissolution of USSR a bad thing:Services such healthcare,education are not free
#
# Variable: USSRNEWK - Dissolution of USSR a bad thing: The number of workplaces has declined
#
# Variable: USSRNETR - Dissolution of USSR a bad thing: Our country has lost territories
#
# Variable: USSRNEIN - Dissolution of USSR a bad thing: The gap between rich and poor has deepened
#
# Variable: USSRNEOT - Dissolution of USSR a bad thing: Other
#
# Variable: ICITLAW - Important for a good citizen: always obey laws?
#
# Variable: ICITGOV - Important for a good citizen: support the government on every occasion?
#
# Variable: ICITVOTE - Important for a good citizen: vote in elections?
#
# Variable: ICITTRAD - Important for a good citizen: protect traditions?
#
# Variable: IMPGCVW - Important for a good citizen: do volunteer work?
#
# Variable: ICITHELP - Important for a good citizen: support people who are worse off than themselves?
#
# Variable: ICITOPP - Important for a good citizen: be critical towards the government?
#
# Variable: USSRNEOO - Dissolution of USSR a bad thing: Other specified
#
# Variable: CNTRDEM - How much of a democracy is COUNTRY today?
#
# Variable: ATTDEM - Which of these three statements is closest to your opinion?
#
# Variable: ECOINVEST - Which of the following statements do you agree with?
#
# Variable: AMULSAR - Do you approve the Amulsar mining project?
#
# Variable: GLWARM - Do you think the global warming has an impact on Armenia?
#
# Variable: ENVPROBAP - Main environmental issue in Armenia: Air pollution
#
# Variable: ENVPROBSEV - Main environmental issue in Armenia: Pollution and misuse of lake Sevan and othe
#
# Variable: ENVPROBPL - Main environmental issue in Armenia: Misuse of plastic
#
# Variable: ENVPROBTW - Main environmental issue in Armenia: Poor trash and waste management (misuse of
#
# Variable: ENVPROBTR - Main environmental issue in Armenia: Heavy traffic
#
# Variable: ENVPROBGMF - Main environmental issue in Armenia: Genetically modified food
#
# Variable: ENVPROBCC - Main environmental issue in Armenia: Climate change
#
# Variable: ENVPROBOZ - Main environmental issue in Armenia: Ozone layer depletion
#
# Variable: ENVPROBEC - Main environmental issue in Armenia: Misuse of Earth's crust
#
# Variable: ENVPROBEA - Main environmental issue in Armenia: Extinction of animal species
#
# Variable: ENVPROBRW - Main environmental issue in Armenia: Radioactive waste
#
# Variable: ENVPROBOT - Main environmental issue in Armenia: Other
#
# Variable: ENVPROBO - Main environmental issue in Armenia: Other specified
#
# Variable: NK4_1 - How likely is it to find a solution to the Nagorno-Karabakh conflict through pea
#
# Variable: NK4_2 - How likely is it to find a solution to the Nagorno-Karabakh conflict through for
#
# Variable: NK5AR_1 - To what extent do you accept having Nagorno-Karabakh as a formal part of Armenia
#
# Variable: NK5AR_2 - To what extent do you accept having Nagorno-Karabakh as an independent country
#
# Variable: NK5AR_3 - To what extent do you accept creating a special administrative region that will
#
# Variable: NK5AR_4 - To what extent do you accept having Nagorno-Karabakh with a high degree of auton
#
# Variable: NK5AR_5 - To what extent do you accept having Nagorno-Karabakh in Azerbaijan without auton
#
# Variable: GERUAVO - Agree/disagree: the 2008 war between Russia and Georgia could have been avoided?
#
# Variable: WARSTRT - In your opinion, which side started the war in August, 2008?
#
# Variable: WARSTRO - In your opinion, which side started the war in August, 2008? Other specified
#
# Variable: RESABKH - Have you heard about conflict in Abkhazia?
#
# Variable: ABKGNOA - To what extent do you accept:Abkhazia as formal part of Georgia,without autonomy
#
# Variable: ABKGHIA - To what extent do you accept:Abkhazia with a high autonomy degree within Georgia
#
# Variable: ABKGCONF - To what extent do you accept:Confederation state between Georgia and Abkhazia
#
# Variable: ABKGIND - To what extent do you accept:Abkhazia as an independent country
#
# Variable: ABKGRUS - To what extent do you accept:Abkhazia as a formal part of Russia
#
# Variable: RESRSOC - Have you heard about conflict in South Ossetia?
#
# Variable: SOGNOA - To what extent do you accept:South Ossetia as a part of Georgia,without autonomy
#
# Variable: SOGHIA - To what extent do you accept:South Ossetia - high autonomy degree within Georgia
#
# Variable: SOGCONF - To what extent do you accept:Confederation between Georgia and South Ossetia
#
# Variable: SOGIND - To what extent do you accept:South Ossetia as an independent country
#
# Variable: SOGRUS - To what extent do you accept:South Ossetia as a formal part of Russia
#
# Variable: EMPLSIT - Which of the following best describes your primary activity or situation?
#
# Variable: UNEMYRS - From which year have you not had a job?
#
# Variable: INTSTJOB - Are you currently interested in a job, or not?
#
# Variable: LOOKJOB - Have you been looking for a job during the past four weeks, or not?
#
# Variable: JOBSTART - Would you be able to start working within the next 14 days?
#
# Variable: WORKTYP - Which of the following best describes your status and the type of workplace?
#
# Variable: WORKYRS - From which year have you been working at this workplace?
#
# Variable: WORKSEC - Which of the following best describes the sector in which you work?
#
# Variable: JOBSARFN - Overall, how satisfied or dissatisfied are you with your job?
#
# Variable: ILOLFC1 - Did you help without being paid in any kind of business run by your household?
#
# Variable: ILOLFC2 - In the last week did you work for a wage, salary, commission or any payment
#
# Variable: PERSINC - Your personal monetary income last month?
#
# Variable: GETJOBF - Which factor do you consider most important for getting a good job?
#
# Variable: NEWHHJOB - Has anybody in your household started a new job during the last 12 months?
#
# Variable: JOBLOST - Has anybody in your household lost job during the last 12 months?
#
# Variable: BANKACC - Do you have a bank account or a bank card?
#
# Variable: FEELDEBR - In 2018, Government annulled certain part of loans. How do you feel about this?
#
# Variable: BENFDEBY - Did you benefit from debt relief program?
#
# Variable: BENFDEBF - Did your family member benefit from debt relief program?
#
# Variable: BENFDEBA - Did your acquaintances benefit from debt relief program?
#
# Variable: ETHNIC - Which ethnic group do you consider yourself a part of?
#
# Variable: EDUYRS - Years in formal education
#
# Variable: RESPEDU - What is the highest level of education you have achieved to date?
#
# Variable: RFAEDUC - What is the highest level of education your father has achieved?
#
# Variable: RMOEDUC - What is the highest level of education your mother has achieved
#
# Variable: FLMANDSC - Which foreign language should be mandatory in secondary schools?
#
# Variable: FLMANDSO - Which foreign language should be mandatory in secondary schools? Other specified
#
# Variable: KNOWRUS - Ability in Russian
#
# Variable: KNOWENG - Ability in English
#
# Variable: KNOWOTH - Ability in other foreign language
#
# Variable: COMPABL - Ability in computer
#
# Variable: SECNDLAAP - Second language used in everyday life-Abkhaz
#
# Variable: SECNDLAAR - Second language used in everyday life-Arabic
#
# Variable: SECNDLAHY - Second language used in everyday life-Armenian
#
# Variable: SECNDLAAS - Second language used in everyday life-Assyrian
#
# Variable: SECNDLAAZ - Second language used in everyday life-Azerbaijani
#
# Variable: SECNDLAAV - Second language used in everyday life-Avar
#
# Variable: SECNDLANGKA - Second language used in everyday life-Georgian
#
# Variable: SECNDLANHE - Second language used in everyday life-Greek
#
# Variable: SECNDLAEN - Second language used in everyday life-English
#
# Variable: SECNDLAZA - Second language used in everyday life-Kurdish languages
#
# Variable: SECNDLAMR - Second language used in everyday life-Mingrelian
#
# Variable: SECNDLAOS - Second language used in everyday life-Ossetian
#
# Variable: SECNDLAOT - Second language used in everyday life-Other
#
# Variable: SECNDLARU - Second language used in everyday life-Russian
#
# Variable: SECNDLASV - Second language used in everyday life-Svan
#
# Variable: SECNDLATR - Second language used in everyday life-Turkish
#
# Variable: SECNDLAOO - Second language used in everyday life-Other specified
#
# Variable: FRQINTR - How often do you use the Internet?
#
# Variable: INTACEM - Most frequent Internet activity: Emails
#
# Variable: INTASKY - Most frequent Internet activity: Skype
#
# Variable: INTACFB - Most frequent Internet activity: Facebook
#
# Variable: INTACSN - Most frequent Internet activity: Other social networking
#
# Variable: INTACFD - Most frequent Internet activity: Forum discussions
#
# Variable: INTACBL - Most frequent Internet activity: Blogs
#
# Variable: INTACIN - Most frequent Internet activity: Search for information
#
# Variable: INTACSH - Most frequent Internet activity: Shopping
#
# Variable: INTACNW - Most frequent Internet activity: News
#
# Variable: INTACEN - Most frequent Internet activity: Music, videos, movies
#
# Variable: INTAGAME - Most frequent Internet activity: Play online games
#
# Variable: INTABET - Most frequent Internet activity: Gambling, betting
#
# Variable: INTACDW - Most frequent Internet activity: Visit dating websites
#
# Variable: INTACOT - Most frequent Internet activity: Other
#
# Variable: INTACOO - Most frequent Internet activity: Other specified
#
# Variable: GAMSOC - Do you think gambling/betting has a negative impact on our society?
#
# Variable: GAMGOV - Do you think gambling advertising on social media and other platforms should be
#
# Variable: GAMIND - Speaking about the past 12 months, have you gambled or placed a bet?
#
# Variable: RELGION - Which religion or denomination, if any, do you consider yourself belong to?
#
# Variable: RELSERV - How often do you attend religious services?
#
# Variable: RELFAST - How often do you fast when it is required by your religion?
#
# Variable: RELIMP - How important is religion in your daily life?
#
# Variable: EMIGRAT - If you had a chance, would you leave forever to live somewhere else?
#
# Variable: MIGSHRT - Would you leave for a certain period of time to live somewhere else?
#
# Variable: LIVEREG - Are you registered in a place where you live now?
#
# Variable: RESPDOB - Respondent's year of birth
#
# Variable: RESPPOB - Respondent's place of birth
#
# Variable: RESPEMP - Are you currently employed?
#
# Variable: RESPTRW - Has respondent traveled for work outside settlement?
#
# Variable: RESPTRP - Respondent's travel place for work (inside country)
#
# Variable: RESPTRA - Has respondent traveled for work abroad?
#
# Variable: RESPTAP - Respondent's travel place for work (abroad)
#
# Variable: RESPMAR - What is your current marital status?
#
# Variable: RESPMRAGE - Respondent's age when s/he got married
#
# Variable: HHM2RELR - Second HH member: relationship to the respondent
#
# Variable: HHM2SEX - Second HH member: gender
#
# Variable: HHM2DOB - Second HH member: year of birth
#
# Variable: HHM2POB - Second HH member: place of birth
#
# Variable: HHM2EMP - Second HH member: employed?
#
# Variable: HHM2TRW - Has 2nd HH member traveled for work outside settlement?
#
# Variable: HHM2TRP - 2nd HH member's travel place for work (inside country)
#
# Variable: HHM2TRA - Has 2nd HH member traveled for work abroad?
#
# Variable: HHM2TAP - 2nd HH member's travel place for work (abroad)
#
# Variable: HHM2MAR - Second HH member: marital status
#
# Variable: HHM2MRAGE - 2nd HH member: Age when s/he got married
#
# Variable: HHM2EDU - 2nd HH member: Level of education achieved to date
#
# Variable: HHM3RELR - Third HH member: relationship to the respondent
#
# Variable: HHM3SEX - Third HH member: gender
#
# Variable: HHM3DOB - Third HH member: year of birth
#
# Variable: HHM3POB - Third HH member: place of birth
#
# Variable: HHM3EMP - Third HH member: employed?
#
# Variable: HHM3TRW - Has 3rd HH member traveled for work outside settlement?
#
# Variable: HHM3TRP - 3rd HH member's travel place for work (inside country)
#
# Variable: HHM3TRA - Has 3rd HH member traveled for work abroad?
#
# Variable: HHM3TAP - 3rd HH member's travel place for work (abroad)
#
# Variable: HHM3MAR - Third HH member: marital status
#
# Variable: HHM3MRAGE - 3rd HH member: Age when s/he got married
#
# Variable: HHM3EDU - 3rd HH member: Level of education achieved to date
#
# Variable: HHM4RELR - 4th HH member: relationship to the respondent
#
# Variable: HHM4SEX - 4th HH member: gender
#
# Variable: HHM4DOB - 4th HH member: year of birth
#
# Variable: HHM4POB - 4th HH member: place of birth
#
# Variable: HHM4EMP - 4th HH member: employed?
#
# Variable: HHM4TRW - Has 4th HH member traveled for work outside settlement?
#
# Variable: HHM4TRP - 4th HH member's travel place for work (inside country)
#
# Variable: HHM4TRA - Has 4th HH member traveled for work abroad?
#
# Variable: HHM4TAP - 4th HH member's travel place for work (abroad)
#
# Variable: HHM4MAR - 4th HH member: marital status
#
# Variable: HHM4MRAGE - 4th HH member: Age when s/he got married
#
# Variable: HHM4EDU - 4th HH member: Level of education achieved to date
#
# Variable: HHM5RELR - 5th HH member: relationship to the respondent
#
# Variable: HHM5SEX - 5th HH member: gender
#
# Variable: HHM5DOB - 5th HH member: year of birth
#
# Variable: HHM5POB - 5th HH member: place of birth
#
# Variable: HHM5EMP - 5th HH member: employed?
#
# Variable: HHM5TRW - Has 5th HH member traveled for work outside settlement?
#
# Variable: HHM5TRP - 5th HH member's travel place for work (inside country)
#
# Variable: HHM5TRA - Has 5th HH member traveled for work abroad?
#
# Variable: HHM5TAP - 5th HH member's travel place for work (abroad)
#
# Variable: HHM5MAR - 5th HH member: marital status
#
# Variable: HHM5MRAGE - 5th HH member: Age when s/he got married
#
# Variable: HHM5EDU - 5th HH member: Level of education achieved to date
#
# Variable: HHM6RELR - 6th HH member: relationship to the respondent
#
# Variable: HHM6SEX - 6th HH member: gender
#
# Variable: HHM6DOB - 6th HH member: year of birth
#
# Variable: HHM6POB - 6th HH member: place of birth
#
# Variable: HHM6EMP - 6th HH member: employed?
#
# Variable: HHM6TRW - Has 6th HH member traveled for work outside settlement?
#
# Variable: HHM6TRP - 6th HH member's travel place for work (inside country)
#
# Variable: HHM6TRA - Has 6th HH member traveled for work abroad?
#
# Variable: HHM6TAP - 6th HH member's travel place for work (abroad)
#
# Variable: HHM6MAR - 6th HH member: marital status
#
# Variable: HHM6MRAGE - 6th HH member: Age when s/he got married
#
# Variable: HHM6EDU - 6th HH member: Level of education achieved to date
#
# Variable: HHM7RELR - 7th HH member: relationship to the respondent
#
# Variable: HHM7SEX - 7th HH member: gender
#
# Variable: HHM7DOB - 7th HH member: year of birth
#
# Variable: HHM7POB - 7th HH member: place of birth
#
# Variable: HHM7EMP - 7th HH member: employed?
#
# Variable: HHM7TRW - Has 7th HH member traveled for work outside settlement?
#
# Variable: HHM7TRP - 7th HH member's travel place for work (inside country)
#
# Variable: HHM7TRA - Has 7th HH member traveled for work abroad?
#
# Variable: HHM7TAP - 7th HH member's travel place for work (abroad)
#
# Variable: HHM7MAR - 7th HH member: marital status
#
# Variable: HHM7MRAGE - 7th HH member: Age when s/he got married
#
# Variable: HHM7EDU - 7th HH member: Level of education achieved to date
#
# Variable: HHM8RELR - 8th HH member: relationship to the respondent
#
# Variable: HHM8SEX - 8th HH member: gender
#
# Variable: HHM8DOB - 8th HH member: year of birth
#
# Variable: HHM8POB - 8th HH member: place of birth
#
# Variable: HHM8EMP - 8th HH member: employed?
#
# Variable: HHM8TRW - Has 8th HH member traveled for work outside settlement?
#
# Variable: HHM8TRP - 8th HH member's travel place for work (inside country)
#
# Variable: HHM8TRA - Has 8th HH member traveled for work abroad?
#
# Variable: HHM8TAP - 8th HH member's travel place for work (abroad)
#
# Variable: HHM8MAR - 8th HH member: marital status
#
# Variable: HHM8MRAGE - 8th HH member: Age when s/he got married
#
# Variable: HHM8EDU - 8th HH member: Level of education achieved to date
#
# Variable: HHM9RELR - 9th HH member: relationship to the respondent
#
# Variable: HHM9SEX - 9th HH member: gender
#
# Variable: HHM9DOB - 9th HH member: year of birth
#
# Variable: HHM9POB - 9th HH member: place of birth
#
# Variable: HHM9EMP - 9th HH member: employed?
#
# Variable: HHM9TRW - Has 9th HH member traveled for work outside settlement?
#
# Variable: HHM9TRP - 9th HH member's travel place for work (inside country)
#
# Variable: HHM9TRA - Has 9th HH member traveled for work abroad?
#
# Variable: HHM9TAP - 9th HH member's travel place for work (abroad)
#
# Variable: HHM9MAR - 9th HH member: marital status
#
# Variable: HHM9MRAGE - 9th HH member: Age when s/he got married
#
# Variable: HHM9EDU - 9th HH member: Level of education achieved to date
#
# Variable: HHM10RELR - 10th HH member: relationship to the respondent
#
# Variable: HHM10SEX - 10th HH member: gender
#
# Variable: HHM10DOB - 10th HH member: year of birth
#
# Variable: HHM10POB - 10th HH member: place of birth
#
# Variable: HHM10EMP - 10th HH member: employed?
#
# Variable: HHM10TRW - Has 10th HH member traveled for work outside settlement?
#
# Variable: HHM10TRP - 10th HH member's travel place for work (inside country)
#
# Variable: HHM10TRA - Has 10th HH member traveled for work abroad?
#
# Variable: HHM10TAP - 10th HH member's travel place for work (abroad)
#
# Variable: HHM10MAR - 10th HH member: marital status
#
# Variable: HHM10MRAGE - 10th HH member: Age when s/he got married
#
# Variable: HHM10EDU - 10th HH member: Level of education achieved to date
#
# Variable: HHM11RELR - 11th HH member: relationship to the respondent
#
# Variable: HHM11SEX - 11th HH member: gender
#
# Variable: HHM11DOB - 11th HH member: year of birth
#
# Variable: HHM11POB - 11th HH member: place of birth
#
# Variable: HHM11EMP - 11th HH member: employed?
#
# Variable: HHM11TRW - Has 11th HH member traveled for work outside settlement?
#
# Variable: HHM11TRP - 11th HH member's travel place for work (inside country)
#
# Variable: HHM11TRA - Has 11th HH member traveled for work abroad?
#
# Variable: HHM11TAP - 11th HH member's travel place for work (abroad)
#
# Variable: HHM11MAR - 11th HH member: marital status
#
# Variable: HHM11MRAGE - 11th HH member: Age when s/he got married
#
# Variable: HHM11EDU - 11th HH member: Level of education achieved to date
#
# Variable: HHM12RELR - 12th HH member: relationship to the respondent
#
# Variable: HHM12SEX - 12th HH member: gender
#
# Variable: HHM12DOB - 12th HH member: year of birth
#
# Variable: HHM12POB - 12th HH member: place of birth
#
# Variable: HHM12EMP - 12th HH member: employed?
#
# Variable: HHM12TRW - Has 12th HH member traveled for work outside settlement?
#
# Variable: HHM12TRP - 12th HH member's travel place for work (inside country)
#
# Variable: HHM12TRA - Has 12th HH member traveled for work abroad?
#
# Variable: HHM12TAP - 12th HH member's travel place for work (abroad)
#
# Variable: HHM12MAR - 12th HH member: marital status
#
# Variable: HHM12MRAGE - 12th HH member: Age when s/he got married
#
# Variable: HHM12EDU - 12th HH member: Level of education achieved to date
#
# Variable: HHM13RELR - 13th HH member: relationship to the respondent
#
# Variable: HHM13SEX - 13th HH member: gender
#
# Variable: HHM13DOB - 13th HH member: year of birth
#
# Variable: HHM13POB - 13th HH member: place of birth
#
# Variable: HHM13EMP - 13th HH member: employed?
#
# Variable: HHM13TRW - Has 13th HH member traveled for work outside settlement?
#
# Variable: HHM13TRP - 13th HH member's travel place for work (inside country)
#
# Variable: HHM13TRA - Has 13th HH member traveled for work abroad?
#
# Variable: HHM13TAP - 13th HH member's travel place for work (abroad)
#
# Variable: HHM13MAR - 13th HH member: marital status
#
# Variable: HHM13MRAGE - 13th HH member: Age when s/he got married
#
# Variable: HHM13EDU - 13th HH member: Level of education achieved to date
#
# Variable: HHM14RELR - 14th HH member: relationship to the respondent
#
# Variable: HHM14SEX - 14th HH member: gender
#
# Variable: HHM14DOB - 14th HH member: year of birth
#
# Variable: HHM14POB - 14th HH member: place of birth
#
# Variable: HHM14EMP - 14th HH member: employed?
#
# Variable: HHM14TRW - Has 14th HH member traveled for work outside settlement?
#
# Variable: HHM14TRP - 14th HH member's travel place for work (inside country)
#
# Variable: HHM14TRA - Has 14th  HH member traveled for work abroad?
#
# Variable: HHM14TAP - 14th HH member's travel place for work (abroad)
#
# Variable: HHM14MAR - 14th  HH member: marital status
#
# Variable: HHM14MRAGE - 14th HH member: Age when s/he got married
#
# Variable: HHM14EDU - 14th HH member: Level of education achieved to date
#
# Variable: HELPA - Did the respondent get help while answering the question of section A?
#
# Variable: ECONSTN - Current economic situation of your household:
#
# Variable: OWNCOTV - Does your household own a color TV?
#
# Variable: NUMCOTV - How many color TVs does your household own?
#
# Variable: OWNDIGC - Does your household own a digital photo camera?
#
# Variable: NUMDIGC - How many digital photo cameras does your household own?
#
# Variable: OWNWASH - Does your household own a washing machine?
#
# Variable: NUMWASH - How many washing machines does your household own?
#
# Variable: OWNFRDG - Does your household own a refrigerator?
#
# Variable: NUMFRDG - How many refrigerators does your household own?
#
# Variable: OWNAIRC - Does your household own an air conditioner?
#
# Variable: NUMAIRC - How many air conditioners does your household own?
#
# Variable: OWNCARS - Does your household own a car?
#
# Variable: NUMCARS - How many cars does your household own?
#
# Variable: OWNLNDP - Does your household own a land line phone?
#
# Variable: OWNCELL - Does your household own a cell phone?
#
# Variable: NUMCELL - How many cell phones does your household own?
#
# Variable: OWNPCELL - Do you personally own a cell phone?
#
# Variable: NUMPCELL - How many cell phones do you personally own?
#
# Variable: CELLINTH - Do any of your HH members have Internet access from a cell phone?
#
# Variable: OWNCOMP - Does your household own a personal computer?
#
# Variable: NUMCOMP - How many personal computers does your household own?
#
# Variable: WEBHOMEH - Does any of your HH members access the Internet from a home computer?
#
# Variable: NOMONFD - How often did you not have enough money to buy food?
#
# Variable: INCSOUCO - HH source of income: Internal remittances
#
# Variable: INCSOUAB - HH source of income: International remittances
#
# Variable: INCSOUAG - HH source of income: Sales of agricultural products
#
# Variable: INCSOUSL - HH source of income: Salaries
#
# Variable: INCSOUGO - HH source of income: Pensions or benefits
#
# Variable: INCSOURE - HH source of income: Income from renting
#
# Variable: INCSOUPR - HH source of income: Income from property sales
#
# Variable: INCSOUIN - HH source of income: Interest
#
# Variable: INCSOUOT - HH source of income: Other
#
# Variable: MONYTOT - HH monetary income last month
#
# Variable: SPENDMO - HH spending last month
#
# Variable: SAVINGS - Does your household currently have any savings?
#
# Variable: DEBTSHH - Does your household currently have any debts?
#
# Variable: FOODDBT - How often has your household borrowed money to buy food?
#
# Variable: UTILDBT - How often has your household borrowed money to pay for utilities?
#
# Variable: CURRUNG - Ladder: current HH situation
#
# Variable: FUTRUNG - Ladder: HH situation in 5 years
#
# Variable: RELCOND - Relative economic condition of the HH
#
# Variable: MININCR - What minimal monthly income would enable your household live a normal life?
#
# Variable: HELPC - Did the respondent get help while answering the question of section C?
#
# Variable: LISTENO - Could anybody but you and the respondent listen to the answers?
#
# Variable: FRQDIST - How often was the respondent distracted during the interview?
#
# Variable: FRQUNDST - How often did you feel that the respondent did not understand the questions?
#
# Variable: FRQSHCD - How often did you feel the respondent was reluctant to use the show cards?
#
# Variable: RESPINL - How would you rate the respondents level of intelligence?
#
# Variable: RESPSINC - How would you evaluate sincerity of respondents answers?
#
# Variable: RESPTIR - How tired was the respondent in the end of the interview?
#
# Variable: ACCEPT - Interview acceptance
#
# Variable: SUBSTRATUM - Substratum
#
# Variable: C1_R - 1st contact result
#
# Variable: C1_DATE - 1st contact date
#
# Variable: C1_TIME - 1st contact time
#
# Variable: C2_R - 2nd contact result
#
# Variable: C2_DATE - 2nd contact date
#
# Variable: C2_TIME - 2nd contact time
#
# Variable: C3_R - 3rd contact result
#
# Variable: C3_DATE - 3rd contact date
#
# Variable: C3_TIME - 3rd contact time
#
# Variable: INT_DATE - Interview date
#
# Variable: INT_START - Interview start time
#
# Variable: INT_END - Interview end time
#
# Variable: INT_DUR - Interview duration
#
# Variable: HHSIZE - Number of all household members
#
# Variable: HHASIZE - Number of adult household members
#
# Variable: INTLANG - Interview language

# %% [markdown]
# ## Understand The Data By Plotting

# %%
import pandas as pd
import pyreadstat
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Map COUNTRY values to their corresponding labels using the metadata
country_labels = meta.value_labels.get(meta.variable_to_label.get('COUNTRY'), {})
df['COUNTRY'] = df['COUNTRY'].map(country_labels)

# Filter the dataset to include only Armenia data
df_armenia = df[df['COUNTRY'] == 'Armenia'].copy()  # Use .copy() to avoid chained assignment

# Convert RESPAGE into age segments
df_armenia['RESPAGE_segmented'] = pd.cut(df_armenia['RESPAGE'], bins=[17, 35, 55, float('inf')], labels=['18-35', '36-55', '56+'])

# List of variables to plot, including the newly segmented RESPAGE
variables_to_plot = [
    'RESPAGE_segmented', 'FATEINLF','BUSINRUS','BUSINTUR', 'BUSINGA', 'NEIGHBOR', 
    'USSRDISS', 'EUSUPP', 'EEUSUPNA', 'EEUNSUW', 'EEUSUPW', 'MAINFRN', 
    'MAINENEM', 'PARTYSUPP', 'WORKTYP', 'PERSINC', 'EDUYRS', 'RFAEDUC', 
    'RMOEDUC', 'RELIMP', 'ECONSTN', 'MONYTOT'
]

# Set up the plot grid
num_plots = len(variables_to_plot)
num_cols = 3
num_rows = (num_plots + num_cols - 1) // num_cols

fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 5 * num_rows))
axes = axes.flatten()  # Flatten the axes array for easy indexing

# Loop through each variable and create a plot
for i, variable in enumerate(variables_to_plot):
    # Copy the column to avoid modifying the original DataFrame
    df_armenia[variable + '_mapped'] = df_armenia[variable]
    
    # If the variable has value labels, selectively map them
    if variable in meta.variable_to_label:
        value_labels = meta.value_labels.get(meta.variable_to_label[variable], {})
        # Map only specific values that have a label, keep numeric values intact
        df_armenia[variable + '_mapped'] = df_armenia[variable].apply(lambda x: value_labels.get(x, x))
    
    # Debug: Check if the column has data before plotting
    print(f"Plotting variable: {variable}")
    print(df_armenia[variable + '_mapped'].value_counts())  # Debugging output
    
    # Plot the distribution of the variable without ordering
    if not df_armenia[variable + '_mapped'].isnull().all():  # Check if the column is not empty
        sns.countplot(data=df_armenia, x=variable + '_mapped', ax=axes[i])
        axes[i].set_title(f'Distribution of {variable} in Armenia')
        axes[i].set_xlabel(variable)
        axes[i].set_ylabel('Count')
        axes[i].tick_params(axis='x', rotation=45)
    else:
        axes[i].set_visible(False)  # Hide the plot if there's no data

# Remove any empty subplots
for j in range(i + 1, num_rows * num_cols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# Plotting variable: RESPAGE_segmented
# RESPAGE_segmented_mapped
# 56+      644
# 36-55    478
# 18-35    369
# Name: count, dtype: int64
# Plotting variable: FATEINLF
# FATEINLF_mapped
# People shape their fate themselves          378
# 5.0                                         364
# Everything in life is determined by fate    190
# 8.0                                         128
# 7.0                                         114
# 6.0                                         107
# 9.0                                          61
# 3.0                                          57
# 4.0                                          47
# 2.0                                          38
# Don't know                                    6
# Refuse to answer                              1
# Name: count, dtype: int64
# Plotting variable: BUSINRUS
# BUSINRUS_mapped
# Approve             1265
# Disapprove           200
# Don't know            25
# Refuse to answer       1
# Name: count, dtype: int64
# Plotting variable: BUSINTUR
# BUSINTUR_mapped
# Disapprove          1089
# Approve              379
# Don't know            22
# Refuse to answer       1
# Name: count, dtype: int64
# Plotting variable: BUSINGA
# BUSINGA_mapped
# Disapprove          1378
# Approve               85
# Don't know            27
# Refuse to answer       1
# Name: count, dtype: int64
# Plotting variable: NEIGHBOR
# NEIGHBOR_mapped
# I would not wish any of these people as my neighbors         459
# Homosexuals                                                  338
# Drug addicts                                                 332
# Criminals                                                    274
# People following a religion that is different to yours        36
# Don't know                                                    25
# Black people                                                  10
# People having political views that are different to yours      6
# Other                                                          6
# Europeans who come to live in COUNTRY and want to stay         3
# Asians who come to live in COUNTRY and want to stay            1
# Refuse to answer                                               1
# Name: count, dtype: int64
# Plotting variable: USSRDISS
# USSRDISS_mapped
# A bad thing         652
# A good thing        619
# Don't know          218
# Refuse to answer      2
# Name: count, dtype: int64
# Plotting variable: EUSUPP
# EUSUPP_mapped
# Rather support                                 432
# Don't know                                     382
# Partially support, partially do not support    335
# Fully support                                  161
# Rather not support                              89
# Do not support at all                           88
# Refuse to answer                                 4
# Name: count, dtype: int64
# Plotting variable: EEUSUPNA
# EEUSUPNA_mapped
# Rather support                                438
# Don't know                                    328
# Partially support, partially don’t support    325
# Fully support                                 260
# Rather not support                             90
# Don’t support at all                           48
# Refuse to answer                                2
# Name: count, dtype: int64
# Plotting variable: EEUNSUW
# EEUNSUW_mapped
# Legal skip                                             1353
# It would restrict our independence                       30
# Peoples economic conditions would worsen                 23
# It would harm our culture and traditions                 18
# Don't know                                               18
# Other                                                    16
# We would be less protected from foreign threats          13
# Everyday life will become more dangerous, less safe       8
# It would hinder our relations with the West               8
# It will not benefit my country                            4
# Name: count, dtype: int64
# Plotting variable: EEUSUPW
# EEUSUPW_mapped
# Legal skip                                                                           793
# Membership in the Eurasian Union would help strengthen relations with Russia         194
# People's economic conditions would improve                                           161
# We would be better protected from foreign treats                                     138
# Don't know                                                                            65
# We would have a better chance to restore its territorial integrity                    59
# Membership in the Eurasian Union would result in improved safety in everyday life     41
# Other                                                                                 25
# I would be able to travel to the Eurasian Union countries without a visa              14
# Refuse to answer                                                                       1
# Name: count, dtype: int64
# Plotting variable: MAINFRN
# MAINFRN_mapped
# Russia                852
# No one                267
# France                155
# Don't know             63
# Our country itself     60
# Iran                   46
# USA                    19
# Germany                 7
# Italy                   5
# China                   5
# Belarus                 2
# Sweden                  2
# Interviewer error       2
# Canada                  1
# India                   1
# Switzerland             1
# Nagorno-Karabakh        1
# Cyprus                  1
# Syria                   1
# Name: count, dtype: int64
# Plotting variable: MAINENEM
# MAINENEM_mapped
# Azerbaijan           1106
# Turkey                350
# Don't know             16
# Refuse to answer        4
# No one                  4
# Israel                  4
# Afganistan              2
# Everybody               2
# Georgia                 1
# France                  1
# Interviewer error       1
# Name: count, dtype: int64
# Plotting variable: PARTYSUPP
# PARTYSUPP_mapped
# There is no such party               596
# Civil Contract                       542
# Prosperous Armenia                   150
# Bright Armenia                        62
# Don't know                            53
# Refuse to answer                      26
# Armenian Revolutionary Federation     18
# Sasna Tsrer Party                     16
# Republican Party of Armenia           11
# Other                                  9
# Hanrapetutyun Party                    4
# Free Democrats                         3
# Mission Party                          1
# Name: count, dtype: int64
# Plotting variable: WORKTYP
# WORKTYP_mapped
# Legal skip                                                  887
# Employee in a medium sized or big local business            186
# Employee in a state organization, company, or enterprise    186
# Run my own business, Self-employed without employees        149
# Other                                                        25
# Run my own business, Self-employed with employees            22
# Employee in a small local business                           16
# Employee in a foreign or international organization          13
# Employee in a local or international NGO                      5
# Refuse to answer                                              1
# Don't know                                                    1
# Name: count, dtype: int64
# Plotting variable: PERSINC
# PERSINC_mapped
# USD 251 – 400         381
# USD 101 – 250         336
# Up to USD 50          304
# USD 401 – 800         161
# USD 51– 100            95
# Refuse to answer       76
# USD 801 – 1200         56
# Don't know             40
# 0                      28
# USD 1200 - 2000         9
# More than USD 2000      5
# Name: count, dtype: int64
# Plotting variable: EDUYRS
# EDUYRS_mapped
# 10.0                 528
# 13.0                 173
# 14.0                 157
# 15.0                 154
# 12.0                 132
# 8.0                   91
# 16.0                  70
# 11.0                  65
# 17.0                  36
# 18.0                  21
# 19.0                  14
# 9.0                   12
# 7.0                   11
# 20.0                   9
# 21.0                   4
# 5.0                    3
# 4.0                    3
# 0.0                    2
# Interviewer error      1
# 25.0                   1
# Refuse to answer       1
# 2.0                    1
# 3.0                    1
# 6.0                    1
# Name: count, dtype: int64
# Plotting variable: RFAEDUC
# RFAEDUC_mapped
# Competed secondary education      667
# Secondary technical education     276
# Completed higher education        219
# Incomplete secondary education    141
# Primary education                  98
# Don't know                         47
# No primary education               28
# Incomplete higher education        14
# Post-graduate degree                1
# Name: count, dtype: int64
# Plotting variable: RMOEDUC
# RMOEDUC_mapped
# Competed secondary education      683
# Secondary technical education     258
# Completed higher education        190
# Incomplete secondary education    167
# Primary education                  89
# No primary education               43
# Don't know                         35
# Incomplete higher education        26
# Name: count, dtype: int64
# Plotting variable: RELIMP
# Series([], Name: count, dtype: int64)
# Plotting variable: ECONSTN
# ECONSTN_mapped
# Money is enough for food and clothes, but not enough for expensive durables    669
# Money is enough for food only, but not for clothes                             392
# Money is not enough for food                                                   233
# We can afford to buy some expensive durables                                   153
# We can afford to buy anything we need                                           33
# Refuse to answer                                                                11
# Name: count, dtype: int64
# Plotting variable: MONYTOT
# MONYTOT_mapped
# USD 101 – 250         417
# USD 251 – 400         305
# USD 401 – 800         257
# USD 51– 100           168
# Refuse to answer      108
# Don't know             82
# USD 801 – 1200         69
# Up to USD 50           35
# 0                      30
# More than USD 2000     10
# USD 1200 - 2000         9
# Break off               1
# Name: count, dtype: int64

# %% [markdown]
# ### All the label of the data can be access in folder Data file value_label_mapping

# %%
import pandas as pd
import pyreadstat

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# List of variables to explain
variables_to_explain = [
    'RESPAGE', 'FATEINLF','BUSINRUS','BUSINTUR', 'BUSINGA', 'NEIGHBOR', 
    'USSRDISS', 'EUSUPP', 'EEUSUPNA', 'EEUNSUW', 'EEUSUPW', 'MAINFRN', 
    'MAINENEM', 'PARTYSUPP', 'WORKTYP', 'PERSINC', 'EDUYRS', 'RFAEDUC', 
    'RMOEDUC', 'RELIMP', 'ECONSTN', 'MONYTOT'
]

# Prepare a list to store the value: label mappings
value_label_list = []

# Extract value: label mappings for each variable
for variable in variables_to_explain:
    if variable in meta.variable_to_label:
        value_labels = meta.value_labels.get(meta.variable_to_label[variable], {})
        for value, label in value_labels.items():
            value_label_list.append({'Variable': variable, 'Value': value, 'Label': label})

# Convert to DataFrame for easy viewing and export
value_label_df = pd.DataFrame(value_label_list)

# Display the DataFrame
print(value_label_df)

# save the result to a CSV file
value_label_df.to_csv('./data/value_label_mappings.csv', index=False)
# Out:
#      Variable  Value          Label
# 0     RESPAGE    1.0          18/35
# 1     RESPAGE    2.0          36/55
# 2     RESPAGE    3.0            56+
# 3    FATEINLF   -9.0      Break off
# 4    FATEINLF   -7.0     Legal skip
# ..        ...    ...            ...
# 366   MONYTOT    5.0  USD 251 – 400
# 367   MONYTOT    6.0  USD 101 – 250
# 368   MONYTOT    7.0    USD 51– 100
# 369   MONYTOT    8.0   Up to USD 50
# 370   MONYTOT    9.0              0
#
# [371 rows x 3 columns]

# %% [markdown]
# # SECTION 1
# #### Was the disolution of Soviet Union good or bad thing? USSRDISS

# %% [markdown]
# Answer can be seen from plotting from previous plotting

# %% [markdown]
# ### Respondents who support nationalist or conservative parties are more likely to view the dissolution as a bad thing.
#
#
# ### Respondents with higher personal income are more likely to view the dissolution as a good thing.
#
# ### Respondents with more years of education are more likely to view the dissolution of the Soviet Union as a good thing.
#
# ### Older respondents are more likely to view the dissolution of the Soviet Union as a bad thing compared to younger respondents.

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['USSRDISS', 'PARTYSUPP', 'PERSINC', 'EDUYRS', 'RESPAGE']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()  # Create a copy to avoid the warning

# Map USSRDISS to binary (1 = Good thing, 0 = Bad thing)
df_filtered['USSRDISS_binary'] = df_filtered['USSRDISS'].map({1.0: 1, 2.0: 0})

# 1. Nationalist/Conservative Parties vs. USSRDISS
# We assume nationalist/conservative parties are encoded in PARTYSUPP
parties = df_filtered.groupby('PARTYSUPP')['USSRDISS_binary'].mean()
print("USSRDISS by Political Party (Mean of Binary):")
print(parties)

# 2. Personal Income vs. USSRDISS
income_corr = df_filtered['PERSINC'].corr(df_filtered['USSRDISS_binary'])
print(f"\nCorrelation between Personal Income and View on USSR Dissolution: {income_corr:.4f}")

# 3. Education Years vs. USSRDISS
education_corr = df_filtered['EDUYRS'].corr(df_filtered['USSRDISS_binary'])
print(f"\nCorrelation between Education Years and View on USSR Dissolution: {education_corr:.4f}")

# 4. Age vs. USSRDISS
age_corr = df_filtered['RESPAGE'].corr(df_filtered['USSRDISS_binary'])
print(f"\nCorrelation between Age and View on USSR Dissolution: {age_corr:.4f}")

# Optional: Logistic regression to assess relationships

# Logistic regression for Personal Income
X_income = sm.add_constant(df_filtered['PERSINC'])
model_income = sm.Logit(df_filtered['USSRDISS_binary'], X_income).fit()
print("\nLogistic Regression: Personal Income vs. View on USSR Dissolution")
print(model_income.summary())

# Logistic regression for Education Years
X_edu = sm.add_constant(df_filtered['EDUYRS'])
model_edu = sm.Logit(df_filtered['USSRDISS_binary'], X_edu).fit()
print("\nLogistic Regression: Education Years vs. View on USSR Dissolution")
print(model_edu.summary())

# Logistic regression for Age
X_age = sm.add_constant(df_filtered['RESPAGE'])
model_age = sm.Logit(df_filtered['USSRDISS_binary'], X_age).fit()
print("\nLogistic Regression: Age vs. View on USSR Dissolution")
print(model_age.summary())

# Plot the distribution of opinions on USSR Dissolution by age, income, and education
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
sns.boxplot(x=df_filtered['USSRDISS_binary'], y=df_filtered['RESPAGE'])
plt.title('Age Distribution by View on USSR Dissolution')
plt.xlabel('View on USSR Dissolution (0: Bad, 1: Good)')
plt.ylabel('Age')

plt.subplot(1, 3, 2)
sns.boxplot(x=df_filtered['USSRDISS_binary'], y=df_filtered['PERSINC'])
plt.title('Personal Income by View on USSR Dissolution')
plt.xlabel('View on USSR Dissolution (0: Bad, 1: Good)')
plt.ylabel('Personal Income')

plt.subplot(1, 3, 3)
sns.boxplot(x=df_filtered['USSRDISS_binary'], y=df_filtered['EDUYRS'])
plt.title('Education Years by View on USSR Dissolution')
plt.xlabel('View on USSR Dissolution (0: Bad, 1: Good)')
plt.ylabel('Years in Education')

plt.tight_layout()
plt.show()
# Out:
# USSRDISS by Political Party (Mean of Binary):
# PARTYSUPP
# 101.0    0.557562
# 102.0    1.000000
# 103.0    0.470588
# 104.0    0.414634
# 105.0    0.444444
# 106.0    0.352941
# 107.0    1.000000
# 108.0    0.500000
# 109.0    0.500000
# 301.0    0.422705
# 302.0    0.385093
# 303.0    0.307692
# 304.0    0.217822
# 305.0    0.449275
# 306.0    0.107143
# 307.0    0.666667
# 308.0    0.956522
# 309.0    0.375000
# 999.0    0.500000
# Name: USSRDISS_binary, dtype: float64
#
# Correlation between Personal Income and View on USSR Dissolution: -0.1321
#
# Correlation between Education Years and View on USSR Dissolution: 0.1953
#
# Correlation between Age and View on USSR Dissolution: -0.2738
# Optimization terminated successfully.
#          Current function value: 0.679152
#          Iterations 4
#
# Logistic Regression: Personal Income vs. View on USSR Dissolution
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        USSRDISS_binary   No. Observations:                 1637
# Model:                          Logit   Df Residuals:                     1635
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01277
# Time:                        15:52:04   Log-Likelihood:                -1111.8
# converged:                       True   LL-Null:                       -1126.1
# Covariance Type:            nonrobust   LLR p-value:                 8.222e-08
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9253      0.219      4.234      0.000       0.497       1.354
# PERSINC       -0.1763      0.033     -5.300      0.000      -0.242      -0.111
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.668487
#          Iterations 5
#
# Logistic Regression: Education Years vs. View on USSR Dissolution
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        USSRDISS_binary   No. Observations:                 1637
# Model:                          Logit   Df Residuals:                     1635
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.02827
# Time:                        15:52:04   Log-Likelihood:                -1094.3
# converged:                       True   LL-Null:                       -1126.1
# Covariance Type:            nonrobust   LLR p-value:                 1.470e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.9725      0.234     -8.421      0.000      -2.432      -1.513
# EDUYRS         0.1415      0.018      7.756      0.000       0.106       0.177
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.649590
#          Iterations 5
#
# Logistic Regression: Age vs. View on USSR Dissolution
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        USSRDISS_binary   No. Observations:                 1637
# Model:                          Logit   Df Residuals:                     1635
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.05574
# Time:                        15:52:04   Log-Likelihood:                -1063.4
# converged:                       True   LL-Null:                       -1126.1
# Covariance Type:            nonrobust   LLR p-value:                 3.879e-29
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5646      0.171      9.130      0.000       1.229       1.900
# RESPAGE       -0.0329      0.003    -10.777      0.000      -0.039      -0.027
# ==============================================================================

# %% [markdown]
# ### Respondents who support nationalist or conservative parties are more likely to view the dissolution as a bad thing. Rejected
#
# ### Respondents with higher personal income are more likely to view the dissolution as a good thing. Rejected
#
# ### Respondents with more years of education are more likely to view the dissolution of the Soviet Union as a good thing. Confirmied
#
# ### Older respondents are more likely to view the dissolution of the Soviet Union as a bad thing compared to younger respondents. Confirmid

# %% [markdown]
# # SECTION II WHO IS THE MAIN ENEMY OF ARMENIA? MAINENEM
#
# #### 1. Respondents who support EU integration are more likely to perceive Russia as Armenia's main enemy.
#
# #### 2. Respondents who consider Russia their main ally are less likely to view Russia as the enemy and more likely to perceive Turkey or Azerbaijan as Armenia's main enemy.
#
# #### 3. Respondents who support nationalist or conservative parties are more likely to perceive Turkey as Armenia's main enemy.
#
# ####  4. Respondents with more years of education are more likely to perceive Russia as Armenia's main enemy.

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Mapping MAINENEM values to countries or groups
mainenem_mapping = {
    1.0: 'Abkhazia', 2.0: 'Afghanistan', 3.0: 'Arabia', 4.0: 'Argentina', 5.0: 'Armenia',
    6.0: 'Australia', 7.0: 'Austria', 8.0: 'Azerbaijan', 9.0: 'Baltic countries',
    10.0: 'Belgium', 11.0: 'Belarus', 12.0: 'Canada', 13.0: 'Cyprus', 14.0: 'Czech republic',
    15.0: 'Denmark', 16.0: 'Eastern European Countries', 17.0: 'Egypt', 18.0: 'Estonia',
    19.0: 'EU', 20.0: 'Finland', 21.0: 'France', 22.0: 'Great Britain', 23.0: 'Germany',
    24.0: 'Greece', 25.0: 'Iceland', 26.0: 'India', 27.0: 'Iran', 28.0: 'Iraq', 29.0: 'Ireland',
    30.0: 'Israel', 31.0: 'Italy', 32.0: 'Japan', 33.0: 'Kazakhstan', 34.0: 'Korea',
    35.0: 'Kyrgyzstan', 36.0: 'Latvia', 37.0: 'Lithuania', 38.0: 'Luxembourg', 39.0: 'Many',
    40.0: 'Mexico', 41.0: 'Moldova', 42.0: 'Muslim countries', 43.0: 'Neighbouring countries',
    44.0: 'Netherlands', 45.0: 'Norway', 46.0: 'Ossetia', 47.0: 'Palestine', 48.0: 'Poland',
    49.0: 'Portugal', 50.0: 'Romania', 51.0: 'Russia', 52.0: 'Slovakia', 53.0: 'Spain',
    54.0: 'Sweden', 55.0: 'Switzerland', 56.0: 'Syria', 57.0: 'Turkey', 58.0: 'UAE',
    59.0: 'Ukraine', 60.0: 'Uruguay', 61.0: 'USA', 62.0: 'Uzbekistan', 63.0: 'Venezuela',
    64.0: 'China', 65.0: 'Nagorno-Karabakh', 66.0: 'Sweden', 67.0: 'Georgia', 81.0: 'Everybody',
    82.0: 'Except Russia', 83.0: 'Foreigners', 84.0: 'Our country itself', 85.0: 'Globalism',
    86.0: 'Local government'
}

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['MAINENEM', 'EUSUPP', 'MAINFRN', 'PARTYSUPP', 'EDUYRS']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Map MAINENEM to specific countries or groups
df_filtered['MAINENEM_mapped'] = df_filtered['MAINENEM'].map(mainenem_mapping)

# Section II Analysis

# 1. EU Integration Support vs. Perception of Russia as the Main Enemy
eu_russia_enemy = pd.crosstab(df_filtered['EUSUPP'], df_filtered['MAINENEM_mapped'] == 'Russia', normalize='index')
print("EU Integration Support vs. Perception of Russia as Armenia's Main Enemy:")
print(eu_russia_enemy)

# 2. Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy
russia_ally_enemy = pd.crosstab(df_filtered['MAINFRN'] == 'Russia', df_filtered['MAINENEM_mapped'], normalize='index')
print("\nRussia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy:")
print(russia_ally_enemy)

# 3. Nationalist/Conservative Parties vs. Perception of Turkey as Main Enemy
turkey_enemy_party = pd.crosstab(df_filtered['PARTYSUPP'], df_filtered['MAINENEM_mapped'] == 'Turkey', normalize='index')
print("\nNationalist/Conservative Parties vs. Perception of Turkey as Armenia's Main Enemy:")
print(turkey_enemy_party)

# 4. Education Years vs. Perception of Russia as Main Enemy
education_russia_enemy_corr = df_filtered['EDUYRS'].corr(df_filtered['MAINENEM_mapped'] == 'Russia')
print(f"\nCorrelation between Education Years and Perception of Russia as Armenia's Main Enemy: {education_russia_enemy_corr:.4f}")

# Optional: Logistic regression to assess relationships

# Logistic regression for EU Support
X_eu = sm.add_constant(df_filtered['EUSUPP'])
model_eu = sm.Logit(df_filtered['MAINENEM_mapped'] == 'Russia', X_eu).fit()
print("\nLogistic Regression: EU Integration Support vs. Perception of Russia as Main Enemy")
print(model_eu.summary())

# Logistic regression for Education Years
X_edu = sm.add_constant(df_filtered['EDUYRS'])
model_edu = sm.Logit(df_filtered['MAINENEM_mapped'] == 'Russia', X_edu).fit()
print("\nLogistic Regression: Education Years vs. Perception of Russia as Main Enemy")
print(model_edu.summary())

# Plotting relationships
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x=df_filtered['MAINENEM_mapped'] == 'Russia', y=df_filtered['EUSUPP'])
plt.title('EU Integration Support by Perception of Russia as Main Enemy')
plt.xlabel('Perceive Russia as Main Enemy')
plt.ylabel('EU Integration Support')

plt.subplot(1, 2, 2)
sns.boxplot(x=df_filtered['MAINENEM_mapped'] == 'Russia', y=df_filtered['EDUYRS'])
plt.title('Education Years by Perception of Russia as Main Enemy')
plt.xlabel('Perceive Russia as Main Enemy')
plt.ylabel('Years in Education')

plt.tight_layout()
plt.show()
# Out:
# EU Integration Support vs. Perception of Russia as Armenia's Main Enemy:
# MAINENEM_mapped     False     True
# EUSUPP
# 1.0              0.836735  0.163265
# 2.0              0.870370  0.129630
# 3.0              0.669261  0.330739
# 4.0              0.604585  0.395415
# 5.0              0.408602  0.591398
#
# Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy:
# MAINENEM_mapped   Armenia  Azerbaijan  Everybody  Foreigners   Georgia  \
# MAINFRN
# False            0.011134    0.409919   0.002024    0.001012  0.001012
#
# MAINENEM_mapped      Iran  Muslim countries  Our country itself    Russia  \
# MAINFRN
# False            0.003036          0.002024            0.001012  0.407895
#
# MAINENEM_mapped    Turkey       USA  Venezuela
# MAINFRN
# False            0.148785  0.011134   0.001012
#
# Nationalist/Conservative Parties vs. Perception of Turkey as Armenia's Main Enemy:
# MAINENEM_mapped     False     True
# PARTYSUPP
# 101.0            0.785075  0.214925
# 102.0            1.000000  0.000000
# 103.0            0.742857  0.257143
# 104.0            0.742574  0.257426
# 105.0            0.833333  0.166667
# 106.0            0.714286  0.285714
# 107.0            0.333333  0.666667
# 108.0            1.000000  0.000000
# 109.0            0.714286  0.285714
# 301.0            0.938547  0.061453
# 302.0            0.966292  0.033708
# 303.0            0.967213  0.032787
# 304.0            0.833333  0.166667
# 305.0            0.891892  0.108108
# 306.0            0.875000  0.125000
# 307.0            0.958333  0.041667
# 308.0            1.000000  0.000000
# 309.0            1.000000  0.000000
# 999.0            1.000000  0.000000
#
# Correlation between Education Years and Perception of Russia as Armenia's Main Enemy: 0.1621
# Optimization terminated successfully.
#          Current function value: 0.639210
#          Iterations 5
#
# Logistic Regression: EU Integration Support vs. Perception of Russia as Main Enemy
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        MAINENEM_mapped   No. Observations:                  988
# Model:                          Logit   Df Residuals:                      986
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.05454
# Time:                        15:59:50   Log-Likelihood:                -631.54
# converged:                       True   LL-Null:                       -667.97
# Covariance Type:            nonrobust   LLR p-value:                 1.391e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.5231      0.283     -8.913      0.000      -3.078      -1.968
# EUSUPP         0.5604      0.070      7.980      0.000       0.423       0.698
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.662831
#          Iterations 5
#
# Logistic Regression: Education Years vs. Perception of Russia as Main Enemy
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        MAINENEM_mapped   No. Observations:                  988
# Model:                          Logit   Df Residuals:                      986
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01960
# Time:                        15:59:50   Log-Likelihood:                -654.88
# converged:                       True   LL-Null:                       -667.97
# Covariance Type:            nonrobust   LLR p-value:                 3.101e-07
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8743      0.308     -6.094      0.000      -2.477      -1.271
# EDUYRS         0.1194      0.024      5.024      0.000       0.073       0.166
# ==============================================================================

# %% [markdown]
# #### 1. Respondents who support EU integration are more likely to perceive Russia as Armenia's main enemy. Confirmied
#
# #### 2. Respondents who consider Russia their main ally are more likely to perceive Turkey or Azerbaijan as Armenia's main enemy. confirmid for Azerbajian. Rejected for Turkey
#
# #### 3. Respondents who support nationalist or conservative parties are more likely to perceive Turkey as Armenia's main enemy. Rejected
#
# ####  4. Respondents with more years of education are more likely to perceive Russia as Armenia's main enemy. Rejected

# %% [markdown]
# # SECTION III WHO IS THE MAIN FRIENDS OF ARMENIA? MAINFRN
#
# #### 1.  Older respondents are more likely to perceive Russia as Armenia's main friend compared to younger respondents.
#
# #### 2.  Respondents from higher-income families are more likely to perceive the European Union (EU) or the United States as Armenia's main friend.
#
# #### 3.  Respondents who perceive Turkey or Azerbaijan as Armenia's main enemy are more likely to perceive Russia as Armenia's main friend.

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Mapping MAINFRN and MAINENEM values to countries or groups
mainfrn_mapping = {
    1.0: 'Abkhazia', 2.0: 'Afghanistan', 3.0: 'Arabia', 4.0: 'Argentina', 5.0: 'Armenia',
    6.0: 'Australia', 7.0: 'Austria', 8.0: 'Azerbaijan', 9.0: 'Baltic countries',
    10.0: 'Belgium', 11.0: 'Belarus', 12.0: 'Canada', 13.0: 'Cyprus', 14.0: 'Czech republic',
    15.0: 'Denmark', 16.0: 'Eastern European Countries', 17.0: 'Egypt', 18.0: 'Estonia',
    19.0: 'EU', 20.0: 'Finland', 21.0: 'France', 22.0: 'Great Britain', 23.0: 'Germany',
    24.0: 'Greece', 25.0: 'Iceland', 26.0: 'India', 27.0: 'Iran', 28.0: 'Iraq', 29.0: 'Ireland',
    30.0: 'Israel', 31.0: 'Italy', 32.0: 'Japan', 33.0: 'Kazakhstan', 34.0: 'Korea',
    35.0: 'Kyrgyzstan', 36.0: 'Latvia', 37.0: 'Lithuania', 38.0: 'Luxembourg', 39.0: 'Many',
    40.0: 'Mexico', 41.0: 'Moldova', 42.0: 'Muslim countries', 43.0: 'Neighbouring countries',
    44.0: 'Netherlands', 45.0: 'Norway', 46.0: 'Ossetia', 47.0: 'Palestine', 48.0: 'Poland',
    49.0: 'Portugal', 50.0: 'Romania', 51.0: 'Russia', 52.0: 'Slovakia', 53.0: 'Spain',
    54.0: 'Sweden', 55.0: 'Switzerland', 56.0: 'Syria', 57.0: 'Turkey', 58.0: 'UAE',
    59.0: 'Ukraine', 60.0: 'Uruguay', 61.0: 'USA', 62.0: 'Uzbekistan', 63.0: 'Venezuela',
    64.0: 'China', 65.0: 'Nagorno-Karabakh', 66.0: 'Sweden', 67.0: 'Georgia', 81.0: 'Everybody',
    82.0: 'Except Russia', 83.0: 'Foreigners', 84.0: 'Our country itself', 85.0: 'Globalism',
    86.0: 'Local government'
}

mainenem_mapping = {
    8.0: 'Azerbaijan', 51.0: 'Russia', 57.0: 'Turkey'
}

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['MAINFRN', 'RESPAGE', 'PERSINC', 'MAINENEM']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Map MAINFRN and MAINENEM to specific countries or groups
df_filtered['MAINFRN_mapped'] = df_filtered['MAINFRN'].map(mainfrn_mapping)
df_filtered['MAINENEM_mapped'] = df_filtered['MAINENEM'].map(mainenem_mapping)

# Section III Analysis

# 1. Older Respondents vs. Perception of Russia as Armenia's Main Friend
age_russia_friend_corr = df_filtered['RESPAGE'].corr(df_filtered['MAINFRN_mapped'] == 'Russia')
print(f"Correlation between Age and Perception of Russia as Armenia's Main Friend: {age_russia_friend_corr:.4f}")

# 2. Higher-Income Families vs. Perception of EU/USA as Armenia's Main Friend
high_income_friend = pd.crosstab(df_filtered['PERSINC'], df_filtered['MAINFRN_mapped'].isin(['EU', 'USA']), normalize='index')
print("\nIncome vs. Perception of EU/USA as Armenia's Main Friend:")
print(high_income_friend)

# 3. Perception of Turkey/Azerbaijan as Enemy vs. Perception of Russia as Friend
enemy_friend_crosstab = pd.crosstab(df_filtered['MAINENEM_mapped'].isin(['Turkey', 'Azerbaijan']), df_filtered['MAINFRN_mapped'] == 'Russia', normalize='index')
print("\nPerception of Turkey/Azerbaijan as Enemy vs. Perception of Russia as Armenia's Main Friend:")
print(enemy_friend_crosstab)

# Optional: Logistic regression to assess relationships

# Logistic regression for Age
X_age = sm.add_constant(df_filtered['RESPAGE'])
model_age = sm.Logit(df_filtered['MAINFRN_mapped'] == 'Russia', X_age).fit()
print("\nLogistic Regression: Age vs. Perception of Russia as Main Friend")
print(model_age.summary())

# Logistic regression for Income (perceiving EU/USA as Armenia's main friend)
X_income = sm.add_constant(df_filtered['PERSINC'])
model_income = sm.Logit(df_filtered['MAINFRN_mapped'].isin(['EU', 'USA']), X_income).fit()
print("\nLogistic Regression: Income vs. Perception of EU/USA as Main Friend")
print(model_income.summary())

# Plotting relationships
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x=df_filtered['MAINFRN_mapped'] == 'Russia', y=df_filtered['RESPAGE'])
plt.title('Age Distribution by Perception of Russia as Main Friend')
plt.xlabel('Perceive Russia as Main Friend')
plt.ylabel('Age')

plt.subplot(1, 2, 2)
sns.boxplot(x=df_filtered['MAINFRN_mapped'].isin(['EU', 'USA']), y=df_filtered['PERSINC'])
plt.title('Income Distribution by Perception of EU/USA as Main Friend')
plt.xlabel('Perceive EU/USA as Main Friend')
plt.ylabel('Income')

plt.tight_layout()
plt.show()
# Out:
# Correlation between Age and Perception of Russia as Armenia's Main Friend: 0.0071
#
# Income vs. Perception of EU/USA as Armenia's Main Friend:
# MAINFRN_mapped     False     True
# PERSINC
# 1.0             0.750000  0.250000
# 2.0             0.500000  0.500000
# 3.0             0.933333  0.066667
# 4.0             0.870130  0.129870
# 5.0             0.898551  0.101449
# 6.0             0.832184  0.167816
# 7.0             0.593496  0.406504
# 8.0             0.881620  0.118380
# 9.0             0.506329  0.493671
#
# Perception of Turkey/Azerbaijan as Enemy vs. Perception of Russia as Armenia's Main Friend:
# MAINFRN_mapped      False     True
# MAINENEM_mapped
# False            0.977901  0.022099
# True             0.282511  0.717489
# Optimization terminated successfully.
#          Current function value: 0.686774
#          Iterations 4
#
# Logistic Regression: Age vs. Perception of Russia as Main Friend
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         MAINFRN_mapped   No. Observations:                 1839
# Model:                          Logit   Df Residuals:                     1837
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:               3.654e-05
# Time:                        16:07:53   Log-Likelihood:                -1263.0
# converged:                       True   LL-Null:                       -1263.0
# Covariance Type:            nonrobust   LLR p-value:                    0.7613
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2668      0.142     -1.879      0.060      -0.545       0.012
# RESPAGE        0.0008      0.003      0.304      0.761      -0.004       0.006
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.508171
#          Iterations 6
#
# Logistic Regression: Income vs. Perception of EU/USA as Main Friend
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         MAINFRN_mapped   No. Observations:                 1839
# Model:                          Logit   Df Residuals:                     1837
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.03229
# Time:                        16:07:53   Log-Likelihood:                -934.53
# converged:                       True   LL-Null:                       -965.71
# Covariance Type:            nonrobust   LLR p-value:                 2.855e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2300      0.269    -11.996      0.000      -3.758      -2.702
# PERSINC        0.2987      0.039      7.650      0.000       0.222       0.375
# ==============================================================================

# %% [markdown]
# #### 1.  Older respondents are more likely to perceive Russia as Armenia's main friend compared to younger respondents. Rejected
#
# #### 2.  Respondents from higher-income families are more likely to perceive the European Union (EU) or the United States as Armenia's main friend. Confirmed
#
# #### 3.  Respondents who perceive Turkey or Azerbaijan as Armenia's main enemy are more likely to perceive Russia as Armenia's main friend. Confirmed

# %% [markdown]
# # SECTION IV  WHAT IS YOUR OPINION ABOUT EU?
#
# #### Younger respondents are more likely to have a positive opinion about the EU compared to older respondents. EUSUPP
#
# #### Respondents who support liberal or pro-European political parties are more likely to have a positive opinion of the EU.
#
# #### Respondents with more years of education are more likely to have a positive opinion of the EU.
#
# #### Respondents who consider religion very important may have a more skeptical opinion of the EU, especially if they perceive it as secular or opposed to traditional values.

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['EUSUPP', 'RESPAGE', 'PARTYSUPP', 'EDUYRS', 'RELIMP']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Convert EUSUPP into a binary variable for logistic regression
# Assuming EUSUPP is on a scale, we convert to binary (1 for positive, 0 for less positive)
df_filtered['EUSUPP_binary'] = df_filtered['EUSUPP'].apply(lambda x: 1 if x >= 4 else 0)

# Map PARTYSUPP to identify liberal or pro-European parties
# Ensure the mapping corresponds to your actual data
liberal_pro_european_parties = {
    1.0: 'Liberal Party',  # Example mapping
    2.0: 'Pro-European Party',  # Example mapping
    # Add actual mappings for your dataset
}

df_filtered['PARTYSUPP_mapped'] = df_filtered['PARTYSUPP'].map(liberal_pro_european_parties)

# Section IV Analysis

# 1. Younger Respondents vs. Positive Opinion of the EU
age_eu_support_corr = df_filtered['RESPAGE'].corr(df_filtered['EUSUPP'])
print(f"Correlation between Age and Positive Opinion of the EU: {age_eu_support_corr:.4f}")

# 2. Support for Liberal/Pro-European Parties vs. Positive Opinion of the EU
liberal_party_eu_support = pd.crosstab(df_filtered['PARTYSUPP_mapped'], df_filtered['EUSUPP_binary'], normalize='index')
print("\nSupport for Liberal/Pro-European Parties vs. Positive Opinion of the EU:")
print(liberal_party_eu_support)

# 3. Education Years vs. Positive Opinion of the EU
education_eu_support_corr = df_filtered['EDUYRS'].corr(df_filtered['EUSUPP'])
print(f"\nCorrelation between Education Years and Positive Opinion of the EU: {education_eu_support_corr:.4f}")

# 4. Religious Importance vs. Skeptical Opinion of the EU
religion_eu_support_corr = df_filtered['RELIMP'].corr(df_filtered['EUSUPP'])
print(f"\nCorrelation between Religious Importance and Opinion of the EU: {religion_eu_support_corr:.4f}")

# Logistic regression for Age
X_age = sm.add_constant(df_filtered['RESPAGE'])
model_age = sm.Logit(df_filtered['EUSUPP_binary'], X_age).fit()
print("\nLogistic Regression: Age vs. Positive Opinion of the EU")
print(model_age.summary())

# Logistic regression for Education Years
X_edu = sm.add_constant(df_filtered['EDUYRS'])
model_edu = sm.Logit(df_filtered['EUSUPP_binary'], X_edu).fit()
print("\nLogistic Regression: Education Years vs. Positive Opinion of the EU")
print(model_edu.summary())

# Logistic regression for Religious Importance
X_religion = sm.add_constant(df_filtered['RELIMP'])
model_religion = sm.Logit(df_filtered['EUSUPP_binary'], X_religion).fit()
print("\nLogistic Regression: Religious Importance vs. Opinion of the EU")
print(model_religion.summary())

# Plotting relationships
plt.figure(figsize=(20, 5))

plt.subplot(1, 4, 1)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['RESPAGE'])
plt.title('Age Distribution by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Age')

plt.subplot(1, 4, 2)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['EDUYRS'])
plt.title('Education Years by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Years in Education')

plt.subplot(1, 4, 3)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['RELIMP'])
plt.title('Religious Importance by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Religious Importance')

plt.tight_layout()
plt.show()
# Out:
# Correlation between Age and Positive Opinion of the EU: -0.1382
#
# Support for Liberal/Pro-European Parties vs. Positive Opinion of the EU:
# Empty DataFrame
# Columns: []
# Index: []
#
# Correlation between Education Years and Positive Opinion of the EU: 0.1244
#
# Correlation between Religious Importance and Opinion of the EU: -0.0603
# Optimization terminated successfully.
#          Current function value: 0.649858
#          Iterations 5
#
# Logistic Regression: Age vs. Positive Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01048
# Time:                        16:15:02   Log-Likelihood:                -651.81
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                 0.0002031
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2958      0.216      6.013      0.000       0.873       1.718
# RESPAGE       -0.0139      0.004     -3.678      0.000      -0.021      -0.006
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.646908
#          Iterations 5
#
# Logistic Regression: Education Years vs. Positive Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01497
# Time:                        16:15:02   Log-Likelihood:                -648.85
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                 8.966e-06
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7573      0.304     -2.492      0.013      -1.353      -0.162
# EDUYRS         0.1007      0.023      4.368      0.000       0.056       0.146
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.654521
#          Iterations 5
#
# Logistic Regression: Religious Importance vs. Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                0.003377
# Time:                        16:15:02   Log-Likelihood:                -656.48
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                   0.03493
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2819      0.357      3.589      0.000       0.582       1.982
# RELIMP        -0.2150      0.103     -2.093      0.036      -0.416      -0.014
# ==============================================================================

# %% [markdown]
# #### Younger respondents are more likely to have a positive opinion about the EU compared to older respondents. EUSUPP Rejected
#
# #### Respondents who support liberal or pro-European political parties are more likely to have a positive opinion of the EU.
#
# #### Respondents with more years of education are more likely to have a positive opinion of the EU. Rejected
#
# #### Respondents who consider religion very important may have a more skeptical opinion of the EU, especially if they perceive it as secular or opposed to traditional values. Rejected

# %%
import pandas as pd
import pyreadstat
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['EUSUPP', 'RESPAGE', 'PARTYSUPP', 'EDUYRS', 'RELIMP']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Convert EUSUPP into a binary variable for logistic regression
# Assuming EUSUPP is on a scale, we convert to binary (1 for positive, 0 for less positive)
df_filtered['EUSUPP_binary'] = df_filtered['EUSUPP'].apply(lambda x: 1 if x >= 4 else 0)

# Map PARTYSUPP to identify all parties
# Use metadata to map party codes to their names
party_labels = meta.value_labels.get(meta.variable_to_label.get('PARTYSUPP', ''), {})
df_filtered['PARTYSUPP_mapped'] = df_filtered['PARTYSUPP'].map(party_labels)

# Section IV Analysis

# 1. Younger Respondents vs. Positive Opinion of the EU
age_eu_support_corr = df_filtered['RESPAGE'].corr(df_filtered['EUSUPP'])
print(f"Correlation between Age and Positive Opinion of the EU: {age_eu_support_corr:.4f}")

# 2. Support for Different Parties vs. Positive Opinion of the EU
party_eu_support = pd.crosstab(df_filtered['PARTYSUPP_mapped'], df_filtered['EUSUPP_binary'], normalize='index')
print("\nSupport for Different Parties vs. Positive Opinion of the EU:")
print(party_eu_support)

# 3. Education Years vs. Positive Opinion of the EU
education_eu_support_corr = df_filtered['EDUYRS'].corr(df_filtered['EUSUPP'])
print(f"\nCorrelation between Education Years and Positive Opinion of the EU: {education_eu_support_corr:.4f}")

# 4. Religious Importance vs. Opinion of the EU
religion_eu_support_corr = df_filtered['RELIMP'].corr(df_filtered['EUSUPP'])
print(f"\nCorrelation between Religious Importance and Opinion of the EU: {religion_eu_support_corr:.4f}")

# Logistic regression for Age
X_age = sm.add_constant(df_filtered['RESPAGE'])
model_age = sm.Logit(df_filtered['EUSUPP_binary'], X_age).fit()
print("\nLogistic Regression: Age vs. Positive Opinion of the EU")
print(model_age.summary())

# Logistic regression for Education Years
X_edu = sm.add_constant(df_filtered['EDUYRS'])
model_edu = sm.Logit(df_filtered['EUSUPP_binary'], X_edu).fit()
print("\nLogistic Regression: Education Years vs. Positive Opinion of the EU")
print(model_edu.summary())

# Logistic regression for Religious Importance
X_religion = sm.add_constant(df_filtered['RELIMP'])
model_religion = sm.Logit(df_filtered['EUSUPP_binary'], X_religion).fit()
print("\nLogistic Regression: Religious Importance vs. Opinion of the EU")
print(model_religion.summary())

# Plotting relationships
plt.figure(figsize=(20, 5))

plt.subplot(1, 4, 1)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['RESPAGE'])
plt.title('Age Distribution by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Age')

plt.subplot(1, 4, 2)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['EDUYRS'])
plt.title('Education Years by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Years in Education')

plt.subplot(1, 4, 3)
sns.boxplot(x=df_filtered['EUSUPP_binary'], y=df_filtered['RELIMP'])
plt.title('Religious Importance by Opinion of the EU')
plt.xlabel('Opinion of the EU')
plt.ylabel('Religious Importance')

plt.tight_layout()
plt.show()
# Out:
# Correlation between Age and Positive Opinion of the EU: -0.1382
#
# Support for Different Parties vs. Positive Opinion of the EU:
# EUSUPP_binary                                   0         1
# PARTYSUPP_mapped
# Alliance of Patriots of Georgia          0.520000  0.480000
# Democratic Movement – United Georgia     0.393939  0.606061
# Free Georgia                             0.384615  0.615385
# Georgian Dream                           0.368778  0.631222
# Labor Party                              0.342466  0.657534
# Movement for Liberty - European Georgia  0.297872  0.702128
# New Political Center – Girchi            0.173913  0.826087
# Other                                    0.450000  0.550000
# Political Platform New Georgia           0.311111  0.688889
# United National Movement                 0.337500  0.662500
#
# Correlation between Education Years and Positive Opinion of the EU: 0.1244
#
# Correlation between Religious Importance and Opinion of the EU: -0.0603
# Optimization terminated successfully.
#          Current function value: 0.649858
#          Iterations 5
#
# Logistic Regression: Age vs. Positive Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01048
# Time:                        17:23:49   Log-Likelihood:                -651.81
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                 0.0002031
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2958      0.216      6.013      0.000       0.873       1.718
# RESPAGE       -0.0139      0.004     -3.678      0.000      -0.021      -0.006
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.646908
#          Iterations 5
#
# Logistic Regression: Education Years vs. Positive Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.01497
# Time:                        17:23:49   Log-Likelihood:                -648.85
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                 8.966e-06
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7573      0.304     -2.492      0.013      -1.353      -0.162
# EDUYRS         0.1007      0.023      4.368      0.000       0.056       0.146
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.654521
#          Iterations 5
#
# Logistic Regression: Religious Importance vs. Opinion of the EU
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          EUSUPP_binary   No. Observations:                 1003
# Model:                          Logit   Df Residuals:                     1001
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                0.003377
# Time:                        17:23:49   Log-Likelihood:                -656.48
# converged:                       True   LL-Null:                       -658.71
# Covariance Type:            nonrobust   LLR p-value:                   0.03493
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2819      0.357      3.589      0.000       0.582       1.982
# RELIMP        -0.2150      0.103     -2.093      0.036      -0.416      -0.014
# ==============================================================================

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Mapping MAINENEM values to countries or groups
mainenem_mapping = {
    1.0: 'Abkhazia', 2.0: 'Afghanistan', 3.0: 'Arabia', 4.0: 'Argentina', 5.0: 'Armenia',
    6.0: 'Australia', 7.0: 'Austria', 8.0: 'Azerbaijan', 9.0: 'Baltic countries',
    10.0: 'Belgium', 11.0: 'Belarus', 12.0: 'Canada', 13.0: 'Cyprus', 14.0: 'Czech republic',
    15.0: 'Denmark', 16.0: 'Eastern European Countries', 17.0: 'Egypt', 18.0: 'Estonia',
    19.0: 'EU', 20.0: 'Finland', 21.0: 'France', 22.0: 'Great Britain', 23.0: 'Germany',
    24.0: 'Greece', 25.0: 'Iceland', 26.0: 'India', 27.0: 'Iran', 28.0: 'Iraq', 29.0: 'Ireland',
    30.0: 'Israel', 31.0: 'Italy', 32.0: 'Japan', 33.0: 'Kazakhstan', 34.0: 'Korea',
    35.0: 'Kyrgyzstan', 36.0: 'Latvia', 37.0: 'Lithuania', 38.0: 'Luxembourg', 39.0: 'Many',
    40.0: 'Mexico', 41.0: 'Moldova', 42.0: 'Muslim countries', 43.0: 'Neighbouring countries',
    44.0: 'Netherlands', 45.0: 'Norway', 46.0: 'Ossetia', 47.0: 'Palestine', 48.0: 'Poland',
    49.0: 'Portugal', 50.0: 'Romania', 51.0: 'Russia', 52.0: 'Slovakia', 53.0: 'Spain',
    54.0: 'Sweden', 55.0: 'Switzerland', 56.0: 'Syria', 57.0: 'Turkey', 58.0: 'UAE',
    59.0: 'Ukraine', 60.0: 'Uruguay', 61.0: 'USA', 62.0: 'Uzbekistan', 63.0: 'Venezuela',
    64.0: 'China', 65.0: 'Nagorno-Karabakh', 66.0: 'Sweden', 67.0: 'Georgia', 81.0: 'Everybody',
    82.0: 'Except Russia', 83.0: 'Foreigners', 84.0: 'Our country itself', 85.0: 'Globalism',
    86.0: 'Local government'
}

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['MAINENEM', 'MAINFRN', 'PARTYSUPP', 'EDUYRS']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Map MAINENEM to specific countries or groups
df_filtered['MAINENEM_mapped'] = df_filtered['MAINENEM'].map(mainenem_mapping)

# Section II Analysis

# 2. Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy
# We consider "Russia", "Turkey", and "Azerbaijan" as main enemies.
enemy_countries = ['Russia', 'Turkey', 'Azerbaijan']
russia_ally_bool = (df_filtered['MAINFRN'] == 51.0).astype(int)
enemy_bool = df_filtered['MAINENEM_mapped'].isin(enemy_countries).astype(int)

russia_ally_enemy = pd.crosstab(russia_ally_bool, enemy_bool, normalize='index')
print("\nRussia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy:")
print(russia_ally_enemy)

# Optional: Logistic regression to assess the relationship

# Logistic regression for Russia as Main Ally vs. Perception of these countries as enemies
X_russia_ally = sm.add_constant(russia_ally_bool)
model_russia_ally = sm.Logit(enemy_bool, X_russia_ally).fit()
print("\nLogistic Regression: Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy")
print(model_russia_ally.summary())

# Plotting relationships
plt.figure(figsize=(8, 5))
sns.barplot(x=russia_ally_bool, y=enemy_bool)
plt.title('Perception of Russia, Turkey, or Azerbaijan as Main Enemy by Russia as Main Ally')
plt.xlabel('Perceive Russia as Main Ally')
plt.ylabel('Proportion perceiving Russia, Turkey, or Azerbaijan as Main Enemy')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()
# Out:
# Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy:
# MAINENEM_mapped         0         1
# MAINFRN
# 0                0.043155  0.956845
# 1                0.014286  0.985714
# Optimization terminated successfully.
#          Current function value: 0.134424
#          Iterations 8
#
# Logistic Regression: Russia as Main Ally vs. Perception of Russia, Turkey, or Azerbaijan as Main Enemy
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        MAINENEM_mapped   No. Observations:                 1162
# Model:                          Logit   Df Residuals:                     1160
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.02688
# Time:                        16:58:12   Log-Likelihood:                -156.20
# converged:                       True   LL-Null:                       -160.51
# Covariance Type:            nonrobust   LLR p-value:                  0.003311
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0988      0.190     16.324      0.000       2.727       3.471
# MAINFRN        1.1353      0.425      2.669      0.008       0.301       1.969
# ==============================================================================

# %%
import pandas as pd
import pyreadstat
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Load the dataset with metadata
file_path = "./CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav"
df, meta = pyreadstat.read_sav(file_path, encoding='UTF-8', disable_datetime_conversion=True)

# Mapping MAINENEM values to countries or groups
mainenem_mapping = {
    1.0: 'Abkhazia', 2.0: 'Afghanistan', 3.0: 'Arabia', 4.0: 'Argentina', 5.0: 'Armenia',
    6.0: 'Australia', 7.0: 'Austria', 8.0: 'Azerbaijan', 9.0: 'Baltic countries',
    10.0: 'Belgium', 11.0: 'Belarus', 12.0: 'Canada', 13.0: 'Cyprus', 14.0: 'Czech republic',
    15.0: 'Denmark', 16.0: 'Eastern European Countries', 17.0: 'Egypt', 18.0: 'Estonia',
    19.0: 'EU', 20.0: 'Finland', 21.0: 'France', 22.0: 'Great Britain', 23.0: 'Germany',
    24.0: 'Greece', 25.0: 'Iceland', 26.0: 'India', 27.0: 'Iran', 28.0: 'Iraq', 29.0: 'Ireland',
    30.0: 'Israel', 31.0: 'Italy', 32.0: 'Japan', 33.0: 'Kazakhstan', 34.0: 'Korea',
    35.0: 'Kyrgyzstan', 36.0: 'Latvia', 37.0: 'Lithuania', 38.0: 'Luxembourg', 39.0: 'Many',
    40.0: 'Mexico', 41.0: 'Moldova', 42.0: 'Muslim countries', 43.0: 'Neighbouring countries',
    44.0: 'Netherlands', 45.0: 'Norway', 46.0: 'Ossetia', 47.0: 'Palestine', 48.0: 'Poland',
    49.0: 'Portugal', 50.0: 'Romania', 51.0: 'Russia', 52.0: 'Slovakia', 53.0: 'Spain',
    54.0: 'Sweden', 55.0: 'Switzerland', 56.0: 'Syria', 57.0: 'Turkey', 58.0: 'UAE',
    59.0: 'Ukraine', 60.0: 'Uruguay', 61.0: 'USA', 62.0: 'Uzbekistan', 63.0: 'Venezuela',
    64.0: 'China', 65.0: 'Nagorno-Karabakh', 66.0: 'Sweden', 67.0: 'Georgia', 81.0: 'Everybody',
    82.0: 'Except Russia', 83.0: 'Foreigners', 84.0: 'Our country itself', 85.0: 'Globalism',
    86.0: 'Local government'
}

# Filter out rows where any relevant variable is below 0 (indicating error or non-response)
relevant_vars = ['MAINENEM', 'MAINFRN', 'PARTYSUPP', 'EDUYRS']
df_filtered = df[(df[relevant_vars] >= 0).all(axis=1)].copy()

# Map MAINENEM to specific countries or groups
df_filtered['MAINENEM_mapped'] = df_filtered['MAINENEM'].map(mainenem_mapping)

# Section II Analysis - Separate Analyses for Azerbaijan and Turkey

# Analysis for Azerbaijan
azerbaijan_bool = df_filtered['MAINENEM_mapped'] == 'Azerbaijan'
russia_ally_bool = (df_filtered['MAINFRN'] == 51.0).astype(int)

azerbaijan_ally_enemy = pd.crosstab(russia_ally_bool, azerbaijan_bool.astype(int), normalize='index')
print("\nRussia as Main Ally vs. Perception of Azerbaijan as Main Enemy:")
print(azerbaijan_ally_enemy)

# Logistic regression for Azerbaijan as Main Enemy
X_azerbaijan = sm.add_constant(russia_ally_bool)
model_azerbaijan = sm.Logit(azerbaijan_bool.astype(int), X_azerbaijan).fit()
print("\nLogistic Regression: Russia as Main Ally vs. Perception of Azerbaijan as Main Enemy")
print(model_azerbaijan.summary())

# Analysis for Turkey
turkey_bool = df_filtered['MAINENEM_mapped'] == 'Turkey'

turkey_ally_enemy = pd.crosstab(russia_ally_bool, turkey_bool.astype(int), normalize='index')
print("\nRussia as Main Ally vs. Perception of Turkey as Main Enemy:")
print(turkey_ally_enemy)

# Logistic regression for Turkey as Main Enemy
X_turkey = sm.add_constant(russia_ally_bool)
model_turkey = sm.Logit(turkey_bool.astype(int), X_turkey).fit()
print("\nLogistic Regression: Russia as Main Ally vs. Perception of Turkey as Main Enemy")
print(model_turkey.summary())

# Plotting relationships
plt.figure(figsize=(16, 5))

# Azerbaijan Plot
plt.subplot(1, 2, 1)
sns.barplot(x=russia_ally_bool, y=azerbaijan_bool.astype(int))
plt.title('Perception of Azerbaijan as Main Enemy by Russia as Main Ally')
plt.xlabel('Perceive Russia as Main Ally')
plt.ylabel('Proportion perceiving Azerbaijan as Main Enemy')
plt.xticks([0, 1], ['No', 'Yes'])

# Turkey Plot
plt.subplot(1, 2, 2)
sns.barplot(x=russia_ally_bool, y=turkey_bool.astype(int))
plt.title('Perception of Turkey as Main Enemy by Russia as Main Ally')
plt.xlabel('Perceive Russia as Main Ally')
plt.ylabel('Proportion perceiving Turkey as Main Enemy')
plt.xticks([0, 1], ['No', 'Yes'])

plt.tight_layout()
plt.show()
# Out:
# Russia as Main Ally vs. Perception of Azerbaijan as Main Enemy:
# MAINENEM_mapped         0         1
# MAINFRN
# 0                0.772321  0.227679
# 1                0.253061  0.746939
# Optimization terminated successfully.
#          Current function value: 0.548777
#          Iterations 5
#
# Logistic Regression: Russia as Main Ally vs. Perception of Azerbaijan as Main Enemy
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        MAINENEM_mapped   No. Observations:                 1162
# Model:                          Logit   Df Residuals:                     1160
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                  0.2017
# Time:                        17:01:18   Log-Likelihood:                -637.68
# converged:                       True   LL-Null:                       -798.81
# Covariance Type:            nonrobust   LLR p-value:                 4.663e-72
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2215      0.092    -13.278      0.000      -1.402      -1.041
# MAINFRN        2.3038      0.139     16.601      0.000       2.032       2.576
# ==============================================================================
#
# Russia as Main Ally vs. Perception of Turkey as Main Enemy:
# MAINENEM_mapped         0         1
# MAINFRN
# 0                0.900298  0.099702
# 1                0.761224  0.238776
# Optimization terminated successfully.
#          Current function value: 0.419408
#          Iterations 6
#
# Logistic Regression: Russia as Main Ally vs. Perception of Turkey as Main Enemy
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        MAINENEM_mapped   No. Observations:                 1162
# Model:                          Logit   Df Residuals:                     1160
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 31 Aug 2024   Pseudo R-squ.:                 0.04008
# Time:                        17:01:18   Log-Likelihood:                -487.35
# converged:                       True   LL-Null:                       -507.70
# Covariance Type:            nonrobust   LLR p-value:                 1.776e-10
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.2005      0.129    -17.091      0.000      -2.453      -1.948
# MAINFRN        1.0411      0.167      6.244      0.000       0.714       1.368
# ==============================================================================

# %% [markdown]
# Was the dissolution of the Soviet Union a good or bad thing? (USSRDISS)
# Respondents who support nationalist or conservative parties are more likely to view the dissolution as a bad thing.
#
# Variable: PARTYSUPP
# Respondents with higher personal income are more likely to view the dissolution as a good thing.
#
# Variable: PERSINC
# Respondents with more years of education are more likely to view the dissolution of the Soviet Union as a good thing.
#
# Variable: EDUYRS
# Older respondents are more likely to view the dissolution of the Soviet Union as a bad thing compared to younger respondents.
#
# Variable: RESPAGE
# Who is the main enemy of Armenia? (MAINENEM)
# Respondents who support EU integration are more likely to perceive Russia as Armenia's main enemy.
#
# Variable: EUSUPP
# Respondents who consider Russia their main ally are less likely to view Russia as the enemy and more likely to perceive Turkey or Azerbaijan as Armenia's main enemy.
#
# Variable: MAINFRN
# Respondents who support nationalist or conservative parties are more likely to perceive Turkey as Armenia's main enemy.
#
# Variable: PARTYSUPP
# Who is the main friend of Armenia? (MAINFRN)
# Older respondents are more likely to perceive Russia as Armenia's main friend compared to younger respondents.
#
# Variable: RESPAGE
# Respondents from higher-income families are more likely to perceive the European Union (EU) or the United States as Armenia's main friend.
#
# Variable: FATEINLF
# Respondents who perceive Turkey or Azerbaijan as Armenia's main enemy are more likely to perceive Russia as Armenia's main friend.
#
# Variable: MAINENEM
# Respondents with more years of education are more likely to perceive Russia as Armenia's main enemy.
#
# Variable: EDUYRS
# What is your opinion about the EU? (EUSUPP)
# Younger respondents are more likely to have a positive opinion about the EU compared to older respondents.
#
# Variable: RESPAGE
# Respondents who support liberal or pro-European political parties are more likely to have a positive opinion of the EU.
#
# Variable: PARTYSUPP
# Respondents with more years of education are more likely to have a positive opinion of the EU.
#
# Variable: EDUYRS
# Respondents who consider religion very important may have a more skeptical opinion of the EU, especially if they perceive it as secular or opposed to traditional values.
#
# Variable: RELIMP

# %% [markdown]
# Liberals - Civil Contract , Bright Armenia, Free Democrats, Hanrapetutyun Party, Mission Party
#
# Conservatives - Armenian Revolutionary Federation, Prosperous Armenia, Sasna Tser Party, Republican Party of Armenia
