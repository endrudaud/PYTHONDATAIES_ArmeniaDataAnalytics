# %%
import pandas as pd
import pyreadstat
import seaborn as sns
import matplotlib.pyplot as plt

df, meta = pyreadstat.read_sav("/Users/tigrankarapetyan/Desktop/PYTHONDATAIES_ArmeniaDataAnalytics/CAUCASUS BAROMETER/cb2019_CB_2019_Regional_25.06.2020.sav", encoding='UTF-8',disable_datetime_conversion=True)
pd.set_option("display.max_columns", None)
#df.head()


# List of variables/columns you want to keep
columns_to_keep = [
    'BUSINUSA', 'BUSINARM', 'BUSINAZE', 'BUSINITA', 'BUSINARA',
    'BUSINGEO', 'BUSINIRA', 'BUSINJEW', 'BUSINKUR', 'BUSINRUS',
    'BUSINTUR', 'BUSINUKR', 'BUSININD', 'BUSINMOL', 'BUSINABK'
]

# Filter the DataFrame to keep only the specified columns
filtered_df = df[columns_to_keep]

#count_ones = (filtered_df == 0).sum()


# Calculate the percentage of 1s
total_counts = len(filtered_df)
percentage_ones = (count_ones / total_counts) * 100

# Create a bar plot for the percentage of 1s
plt.figure(figsize=(14, 8))
percentage_ones.plot(kind='bar', color='skyblue')
plt.title('Percentage of 1s for Each Variable')
plt.xlabel('Variables')
plt.ylabel('Percentage of 1s (%)')
plt.xticks(rotation=45)
plt.show()
